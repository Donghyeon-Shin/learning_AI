# %%
import torch
import torchvision
import torchvision.transforms as transforms

# GPU 설정
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# transforms.Compose : 이미지에 적용할 여러 변환을 묶는 역할
    # transforms.ToTensor() : 이미지를 텐서로 변환 -> 픽셀 값을 0-255 -> 0-1 사이로 정규화
    # transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)) : 각 색상 채널(빨강, 초록, 파랑)의 픽셀 값 범위를 -1 ~ 1 사이로 정규화

transfrom = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

batch_size = 256 # 전체(목표) 배치 크기
sub_batch_size = 32 # 부분 배치 크기

# 데이터셋 다운로드
full_trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transfrom)
import torch
import torchvision
import torchvision.transforms as transforms

# transforms.Compose : 이미지에 적용할 여러 변환을 묶는 역할
    ## transforms.RandomCrop(32, padding=4) : 32x32에서 4픽셀 패딩 후 랜덤 크롭
    ## transforms.RandomHorizontalFlip() : 50% 확률로 좌우 반전
    ## transforms.ToTensor() : 이미지를 텐서로 변환 -> 픽셀 값을 0-255 -> 0-1 사이로 정규화
    ## transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)) : 각 색상 채널(빨강, 초록, 파랑)의 픽셀 값 범위를 -1 ~ 1 사이로 정규화

# 데이터 증강
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])

# 검증/테스트 데이터
transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

batch_size = 256 # 전체(목표) 배치 크기
sub_batch_size = 32 # 부분 배치 크기

# 데이터셋 다운로드
full_trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)

classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# %%
from torch.utils.data import random_split

# Train/Validation 분할 (80:20)
train_size = int(0.8 * len(full_trainset))
val_size = len(full_trainset) - train_size

datasets = random_split(full_trainset, [train_size, val_size])
trainset = datasets[0]  # 학습용
valset = datasets[1]     # 검증용


# 데이터셋 불러오기
# DataLoader : 데이터셋을 배치 단위로 관리하는 역할
    # batch_size : 배치 크기
    # shuffle : 데이터를 섞을지 여부
    # num_workers : 데이터 로드에 사용할 쓰레드 수
train_loader = torch.utils.data.DataLoader(trainset, batch_size=sub_batch_size, shuffle=True, num_workers=0)
val_loader = torch.utils.data.DataLoader(valset, batch_size=sub_batch_size, shuffle=False, num_workers=0)
test_loader = torch.utils.data.DataLoader(testset, batch_size=sub_batch_size, shuffle=False, num_workers=0)

# %%
import torch.nn as nn
import torch.nn.functional as F

# PlainNetBlock : 18 layer plain net의 기본 블록
class PlainNetBlock(nn.Module):
    expansion = 1

    # 초기화 함수
    def __init__(self, in_planes, planes, stride=1):
        super(PlainNetBlock, self).__init__()

        # 첫 번째 컨볼루션 레이어
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)

        # 두 번째 컨볼루션 레이어
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        return out

# ResNetBasicBlock : ResNet의 기본 블록
class ResNetBasicBlock(nn.Module):
    expansion = 1

    # 초기화 함수
    def __init__(self, in_planes, planes, stride=1):
        super(ResNetBasicBlock, self).__init__()

        # 첫 번째 컨볼루션 레이어
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)

        # 두 번째 컨볼루션 레이어
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)

        # 축약 경로(shortcut) 설정
        self.shortcut = nn.Sequential()

        # Input 크기가 변경되는 경우, Output 크기와 일치시키기 위해 1x1 컨볼루션 추가
        if stride != 1 or in_planes != planes * self.expansion:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, planes * self.expansion, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(planes * self.expansion)
            )
    
    # 순전파 함수
    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x) # 축약 경로 추가
        out = F.relu(out)
        return out

# ResNetBottleneck : ResNet의 병목 블록
class ResNetBottleneck(nn.Module):
    expansion = 4

    # 초기화 함수
    def __init__(self, in_planes, planes, stride=1):
        super(ResNetBottleneck, self).__init__()

        # 첫 번째 컨볼루션 레이어
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)

        # 두 번째 컨볼루션 레이어
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)

        # 세 번째 컨볼루션 레이어
        self.conv3 = nn.Conv2d(planes, planes * self.expansion, kernel_size=1, bias=False)
        self.bn3 = nn.BatchNorm2d(planes * self.expansion)

        # 축약 경로(shortcut) 설정
        self.shortcut = nn.Sequential()

        # Input 크기가 변경되는 경우, Output 크기와 일치시키기 위해 1x1 컨볼루션 추가
        if stride != 1 or in_planes != planes * self.expansion:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, planes * self.expansion, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(planes * self.expansion)
            )

    # 순전파 함수
    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = F.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv3(out))
        out += self.shortcut(x) # 축약 경로 추가
        out = F.relu(out)
        return out

# %%
# net class
class Net(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(Net, self).__init__()
        self.in_planes = 64

        # 채널 수 3 -> 64
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)

        # _make_layer 함수 호출하여 여러 개의 블록 그룹 생성
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)

        # average pooling 레이어 사용
        self.avgpool = nn.AdaptiveAvgPool2d((1, 1))
        # 완전 연결 레이어(Fully Connected Layer) 512 * block.expansion -> 10개의 클래스로 분류
        self.fc = nn.Linear(512*block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1) # 첫 번째 블록은 stride, 나머지는 1
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion # 채널 수 증가
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = self.avgpool(out)
        out = out.view(out.size(0), -1)  # 텐서를 평탄화 (배치 크기, 512)
        out = self.fc(out)
        return out

# %%
# 18 layer plain net
planet_18 = Net(PlainNetBlock, [2, 2, 2, 2])
planet_18_loss = []
planet_18_error = []
    
# 18 layer resnet
resnet_18 = Net(ResNetBasicBlock, [2, 2, 2, 2])
resnet_18_loss = []
resnet_18_error = []

# 50 layer resnet
resnet_50 = Net(ResNetBottleneck, [3, 4, 6, 3])
resnet_50_loss = []
resnet_50_error = []

# 모델을 GPU로 이동
planet_18 = planet_18.to(device)
resnet_18 = resnet_18.to(device)
resnet_50 = resnet_50.to(device)

# %%
import torch.optim as optim
import numpy as np

# 크로스 엔트로피 손실 함수 사용
criterion = nn.CrossEntropyLoss()

# 초기 학습률을 더 낮게 설정 (경사 폭발 방지)
# ResNet-50과 같은 깊은 네트워크에서는 더 보수적인 접근 필요

# 모멘텀 0.9, weight_decay 1e-4
planet_18_optimizer = optim.SGD(planet_18.parameters(), lr=0.0001, momentum=0.9, weight_decay=1e-4)
resnet_18_optimizer = optim.SGD(resnet_18.parameters(), lr=0.001, momentum=0.9, weight_decay=1e-4)
resnet_50_optimizer = optim.SGD(resnet_50.parameters(), lr=0.001, momentum=0.9, weight_decay=1e-4)

# 학습률 스케줄링
planet_18_scheduler = optim.lr_scheduler.ReduceLROnPlateau(planet_18_optimizer, mode='min', factor=0.1, patience=5)
resnet_18_scheduler = optim.lr_scheduler.ReduceLROnPlateau(resnet_18_optimizer, mode='min', factor=0.1, patience=5)
resnet_50_scheduler = optim.lr_scheduler.ReduceLROnPlateau(resnet_50_optimizer, mode='min', factor=0.1, patience=5)

# 50번 에포크 학습
num_epochs = 50

# %%
# 평가 함수 (top1 error rate, top5 error rate)
def evaluate_model(model, data_loader, is_top5=False):
    model.eval()
    total_correct = 0
    total_samples = 0

    with torch.no_grad():
        for inputs, labels in data_loader:
            inputs = inputs.to(device)  # GPU로 이동
            labels = labels.to(device)  # GPU로 이동
            
            outputs = model(inputs)
            
            if is_top5:
                _, top5 = outputs.topk(5, dim=1)
                total_correct += (top5 == labels.unsqueeze(1)).any(dim=1).sum().item()
            else:
                _, predicted = torch.max(outputs.data, 1)
                total_correct += (predicted == labels).sum().item()
            total_samples += labels.size(0)

    return (1 - total_correct / total_samples) * 100

# %%
# model 학습 (스케줄링 적용)
for epoch in range(num_epochs):
    running_loss_planet_18 = 0.0
    running_loss_resnet_18 = 0.0
    running_loss_resnet_50 = 0.0

    accumulated_steps = batch_size // sub_batch_size # 누적 배치 크기
    
    print(f"\nEpoch {epoch + 1}/{num_epochs}")
    print(f"Current LR - Planet18: {planet_18_optimizer.param_groups[0]['lr']:.6f}, ResNet18: {resnet_18_optimizer.param_groups[0]['lr']:.6f}, ResNet50: {resnet_50_optimizer.param_groups[0]['lr']:.6f}")
    
    for i, data in enumerate(train_loader, 0):
        inputs, labels = data
        inputs = inputs.to(device)  # GPU로 이동
        labels = labels.to(device)  # GPU로 이동

        # 순전파 + 역전파 + 최적화
        outputs_planet_18 = planet_18(inputs)
        outputs_resnet_18 = resnet_18(inputs)
        outputs_resnet_50 = resnet_50(inputs)

        loss_planet_18 = criterion(outputs_planet_18, labels)
        loss_resnet_18 = criterion(outputs_resnet_18, labels)
        loss_resnet_50 = criterion(outputs_resnet_50, labels)

        loss_planet_18.backward()
        loss_resnet_18.backward()
        loss_resnet_50.backward()

        # 배치 손실 합계 계산
        running_loss_planet_18 += loss_planet_18.item()
        running_loss_resnet_18 += loss_resnet_18.item()
        running_loss_resnet_50 += loss_resnet_50.item()
        
        # 8번마다 파라미터 업데이트(256/32 = 8) -> gradient 누적
        if (i + 1) % accumulated_steps == 0:

            ## planet_18
            planet_18_optimizer.step() # 파라미터 업데이트
            planet_18_optimizer.zero_grad() # 변화도(gradient) 초기화
            
            ## resnet_18
            resnet_18_optimizer.step() # 파라미터 업데이트
            resnet_18_optimizer.zero_grad() # 변화도(gradient) 초기화

            ## resnet_50
            resnet_50_optimizer.step() # 파라미터 업데이트
            resnet_50_optimizer.zero_grad() # 변화도(gradient) 초기화

            # 매번 손실 기록 (8번의 배치 평균)
            avg_loss_planet_18 = running_loss_planet_18 / accumulated_steps
            planet_18_loss.append(avg_loss_planet_18)

            avg_loss_resnet_18 = running_loss_resnet_18 / accumulated_steps
            resnet_18_loss.append(avg_loss_resnet_18)

            avg_loss_resnet_50 = running_loss_resnet_50 / accumulated_steps
            resnet_50_loss.append(avg_loss_resnet_50)

            # print(f"Step {i // accumulated_steps + 1}: planet_18 Loss = {avg_loss_planet_18:.4f}, resnet_18 Loss = {avg_loss_resnet_18:.4f}, resnet_50 Loss = {avg_loss_resnet_50:.4f}")

            # step 24마다 검증 데이터 평가
            if (i // accumulated_steps + 1) % 24 == 0:    
                val_error_planet_18 = evaluate_model(planet_18, val_loader)
                val_error_resnet_18 = evaluate_model(resnet_18, val_loader)
                val_error_resnet_50 = evaluate_model(resnet_50, val_loader)

                planet_18_error.append(val_error_planet_18)
                resnet_18_error.append(val_error_resnet_18)
                resnet_50_error.append(val_error_resnet_50)

                print(f"Step {i // accumulated_steps + 1}: planet_18 Error = {val_error_planet_18:.2f}, resnet_18 Error = {val_error_resnet_18:.2f}, resnet_50 Error = {val_error_resnet_50:.2f}")
                
            # running_loss 초기화 (다음 8번의 배치를 위해)
            running_loss_planet_18 = 0.0
            running_loss_resnet_18 = 0.0
            running_loss_resnet_50 = 0.0

    # 학습 루프가 끝난 후, 남은 그래디언트 처리
    if (len(train_loader) % accumulated_steps) != 0:
        planet_18_optimizer.step()
        planet_18_optimizer.zero_grad()

        resnet_18_optimizer.step()  
        resnet_18_optimizer.zero_grad()

        resnet_50_optimizer.step()
        resnet_50_optimizer.zero_grad()
    
    # 에포크 끝에서 스케줄러 업데이트 (검증 오류율 기준)
    if len(planet_18_error) > 0:
        # 경사 폭발 확인
        print(f"Planet18 last avg_loss_planet_18 : {avg_loss_planet_18}, Resnet18 last avg_loss_resnet_18 : {avg_loss_resnet_18}, Resnet50 last avg_loss_resnet_50 : {avg_loss_resnet_50}")

        planet_18_scheduler.step(planet_18_error[-1])
        resnet_18_scheduler.step(resnet_18_error[-1])
        resnet_50_scheduler.step(resnet_50_error[-1])
# Out:
# Epoch 1/50
# Current LR - Planet18: 0.000100, ResNet18: 0.001000, ResNet50: 0.001000
# Step 24: planet_18 Error = 75.66, resnet_18 Error = 70.02, resnet_50 Error = 82.22
# Step 48: planet_18 Error = 75.72, resnet_18 Error = 89.53, resnet_50 Error = 90.12
# Step 72: planet_18 Error = 68.51, resnet_18 Error = 89.74, resnet_50 Error = 88.43
# Step 96: planet_18 Error = 62.96, resnet_18 Error = 85.42, resnet_50 Error = 80.86
# Step 120: planet_18 Error = 60.93, resnet_18 Error = 83.07, resnet_50 Error = 76.37
# Step 144: planet_18 Error = 60.81, resnet_18 Error = 81.53, resnet_50 Error = 74.65
# Planet18 last avg_loss_planet_18 : 1.5144667327404022, Resnet18 last avg_loss_resnet_18 : 2.091358095407486, Resnet50 last avg_loss_resnet_50 : 1.8957296907901764
#
# Epoch 2/50
# Current LR - Planet18: 0.000100, ResNet18: 0.001000, ResNet50: 0.001000
# Step 24: planet_18 Error = 55.39, resnet_18 Error = 76.93, resnet_50 Error = 72.92
# Step 48: planet_18 Error = 54.94, resnet_18 Error = 77.57, resnet_50 Error = 69.84
# Step 72: planet_18 Error = 57.24, resnet_18 Error = 74.60, resnet_50 Error = 69.00
# Step 96: planet_18 Error = 54.42, resnet_18 Error = 72.47, resnet_50 Error = 70.18
# Step 120: planet_18 Error = 52.79, resnet_18 Error = 73.78, resnet_50 Error = 65.89
# Step 144: planet_18 Error = 50.26, resnet_18 Error = 71.90, resnet_50 Error = 67.29
# Planet18 last avg_loss_planet_18 : 1.3292882144451141, Resnet18 last avg_loss_resnet_18 : 1.9320010989904404, Resnet50 last avg_loss_resnet_50 : 1.8016032874584198
#
# Epoch 3/50
# Current LR - Planet18: 0.000100, ResNet18: 0.001000, ResNet50: 0.001000
# Step 24: planet_18 Error = 50.51, resnet_18 Error = 69.57, resnet_50 Error = 63.23
# Step 48: planet_18 Error = 48.04, resnet_18 Error = 69.06, resnet_50 Error = 63.56
# Step 72: planet_18 Error = 48.62, resnet_18 Error = 65.80, resnet_50 Error = 61.83
# Step 96: planet_18 Error = 44.78, resnet_18 Error = 70.26, resnet_50 Error = 60.59
# Step 120: planet_18 Error = 44.15, resnet_18 Error = 67.35, resnet_50 Error = 59.06
# Step 144: planet_18 Error = 46.25, resnet_18 Error = 65.56, resnet_50 Error = 59.62
# Planet18 last avg_loss_planet_18 : 1.2397672981023788, Resnet18 last avg_loss_resnet_18 : 1.6717625558376312, Resnet50 last avg_loss_resnet_50 : 1.7082896381616592
#
# Epoch 4/50
# Current LR - Planet18: 0.000100, ResNet18: 0.001000, ResNet50: 0.001000
# Step 24: planet_18 Error = 42.52, resnet_18 Error = 60.59, resnet_50 Error = 58.30
# Step 48: planet_18 Error = 45.34, resnet_18 Error = 62.43, resnet_50 Error = 58.58
# Step 72: planet_18 Error = 41.46, resnet_18 Error = 61.07, resnet_50 Error = 57.35
# Step 96: planet_18 Error = 41.22, resnet_18 Error = 60.07, resnet_50 Error = 58.03
# Step 120: planet_18 Error = 41.34, resnet_18 Error = 58.92, resnet_50 Error = 57.04
# Step 144: planet_18 Error = 42.34, resnet_18 Error = 57.97, resnet_50 Error = 54.17
# Planet18 last avg_loss_planet_18 : 0.9235661402344704, Resnet18 last avg_loss_resnet_18 : 1.4989751279354095, Resnet50 last avg_loss_resnet_50 : 1.535836637020111
#
# Epoch 5/50
# Current LR - Planet18: 0.000100, ResNet18: 0.001000, ResNet50: 0.001000
# Step 24: planet_18 Error = 40.56, resnet_18 Error = 57.46, resnet_50 Error = 53.83
# Step 48: planet_18 Error = 37.56, resnet_18 Error = 55.23, resnet_50 Error = 54.31
# Step 72: planet_18 Error = 38.35, resnet_18 Error = 55.06, resnet_50 Error = 53.85
# Step 96: planet_18 Error = 37.22, resnet_18 Error = 55.26, resnet_50 Error = 55.57
# Step 120: planet_18 Error = 37.22, resnet_18 Error = 54.30, resnet_50 Error = 51.57
# Step 144: planet_18 Error = 38.43, resnet_18 Error = 55.69, resnet_50 Error = 53.30
# Planet18 last avg_loss_planet_18 : 0.9613393545150757, Resnet18 last avg_loss_resnet_18 : 1.5371444821357727, Resnet50 last avg_loss_resnet_50 : 1.3914235085248947
#
# Epoch 6/50
# Current LR - Planet18: 0.000100, ResNet18: 0.001000, ResNet50: 0.001000
# Step 24: planet_18 Error = 36.06, resnet_18 Error = 54.23, resnet_50 Error = 54.56
# Step 48: planet_18 Error = 35.43, resnet_18 Error = 53.32, resnet_50 Error = 52.06
# Step 72: planet_18 Error = 34.76, resnet_18 Error = 53.05, resnet_50 Error = 50.90
# Step 96: planet_18 Error = 35.30, resnet_18 Error = 52.29, resnet_50 Error = 49.80
# Step 120: planet_18 Error = 34.30, resnet_18 Error = 50.44, resnet_50 Error = 50.41
# Step 144: planet_18 Error = 32.24, resnet_18 Error = 50.50, resnet_50 Error = 48.20
# Planet18 last avg_loss_planet_18 : 0.9555759504437447, Resnet18 last avg_loss_resnet_18 : 1.4113775938749313, Resnet50 last avg_loss_resnet_50 : 1.6041818857192993
#
# Epoch 7/50
# Current LR - Planet18: 0.000100, ResNet18: 0.001000, ResNet50: 0.001000
# Step 24: planet_18 Error = 34.90, resnet_18 Error = 50.35, resnet_50 Error = 48.92
# Step 48: planet_18 Error = 32.54, resnet_18 Error = 48.96, resnet_50 Error = 46.85
# Step 72: planet_18 Error = 30.93, resnet_18 Error = 50.23, resnet_50 Error = 49.24
# Step 96: planet_18 Error = 31.48, resnet_18 Error = 48.75, resnet_50 Error = 49.72
# Step 120: planet_18 Error = 34.44, resnet_18 Error = 49.07, resnet_50 Error = 45.50
# Step 144: planet_18 Error = 31.52, resnet_18 Error = 48.00, resnet_50 Error = 46.78
# Planet18 last avg_loss_planet_18 : 0.9250344261527061, Resnet18 last avg_loss_resnet_18 : 1.2895157635211945, Resnet50 last avg_loss_resnet_50 : 1.1940794736146927
#
# Epoch 8/50
# Current LR - Planet18: 0.000100, ResNet18: 0.001000, ResNet50: 0.001000
# Step 24: planet_18 Error = 30.12, resnet_18 Error = 47.33, resnet_50 Error = 44.15
# Step 48: planet_18 Error = 30.66, resnet_18 Error = 48.12, resnet_50 Error = 43.86
# Step 72: planet_18 Error = 29.51, resnet_18 Error = 44.20, resnet_50 Error = 42.79
# Step 96: planet_18 Error = 28.29, resnet_18 Error = 47.11, resnet_50 Error = 43.33
# Step 120: planet_18 Error = 30.15, resnet_18 Error = 45.70, resnet_50 Error = 44.68
# Step 144: planet_18 Error = 29.22, resnet_18 Error = 43.69, resnet_50 Error = 42.83
# Planet18 last avg_loss_planet_18 : 0.7119373679161072, Resnet18 last avg_loss_resnet_18 : 1.196358934044838, Resnet50 last avg_loss_resnet_50 : 1.0912889316678047
#
# Epoch 9/50
# Current LR - Planet18: 0.000100, ResNet18: 0.001000, ResNet50: 0.001000
# Step 24: planet_18 Error = 28.86, resnet_18 Error = 44.10, resnet_50 Error = 42.60
# Step 48: planet_18 Error = 27.21, resnet_18 Error = 45.31, resnet_50 Error = 41.27
# Step 72: planet_18 Error = 27.55, resnet_18 Error = 42.60, resnet_50 Error = 39.73
# Step 96: planet_18 Error = 28.80, resnet_18 Error = 41.12, resnet_50 Error = 41.27
# Step 120: planet_18 Error = 27.62, resnet_18 Error = 41.29, resnet_50 Error = 39.62
# Step 144: planet_18 Error = 26.40, resnet_18 Error = 41.64, resnet_50 Error = 39.00
# Planet18 last avg_loss_planet_18 : 0.7498542629182339, Resnet18 last avg_loss_resnet_18 : 1.209130123257637, Resnet50 last avg_loss_resnet_50 : 1.1759168282151222
#
# Epoch 10/50
# Current LR - Planet18: 0.000100, ResNet18: 0.001000, ResNet50: 0.001000
# Step 24: planet_18 Error = 28.28, resnet_18 Error = 40.94, resnet_50 Error = 40.36
# Step 48: planet_18 Error = 26.49, resnet_18 Error = 40.21, resnet_50 Error = 38.10
# Step 72: planet_18 Error = 25.70, resnet_18 Error = 40.28, resnet_50 Error = 37.64
# Step 96: planet_18 Error = 27.64, resnet_18 Error = 39.43, resnet_50 Error = 38.91
# Step 120: planet_18 Error = 27.10, resnet_18 Error = 39.32, resnet_50 Error = 37.05
# Step 144: planet_18 Error = 24.86, resnet_18 Error = 37.25, resnet_50 Error = 39.79
# Planet18 last avg_loss_planet_18 : 0.7722700834274292, Resnet18 last avg_loss_resnet_18 : 1.1709499806165695, Resnet50 last avg_loss_resnet_50 : 1.0690772607922554
#
# Epoch 11/50
# Current LR - Planet18: 0.000100, ResNet18: 0.001000, ResNet50: 0.001000
# Step 24: planet_18 Error = 25.13, resnet_18 Error = 38.18, resnet_50 Error = 37.18
# Step 48: planet_18 Error = 25.26, resnet_18 Error = 38.09, resnet_50 Error = 38.70
# Step 72: planet_18 Error = 24.84, resnet_18 Error = 36.54, resnet_50 Error = 33.90
# Step 96: planet_18 Error = 25.61, resnet_18 Error = 36.46, resnet_50 Error = 34.35
# Step 120: planet_18 Error = 25.43, resnet_18 Error = 35.39, resnet_50 Error = 36.39
# Step 144: planet_18 Error = 25.21, resnet_18 Error = 34.94, resnet_50 Error = 35.10
# Planet18 last avg_loss_planet_18 : 0.5783885270357132, Resnet18 last avg_loss_resnet_18 : 0.8597683757543564, Resnet50 last avg_loss_resnet_50 : 0.833968497812748
#
# Epoch 12/50
# Current LR - Planet18: 0.000100, ResNet18: 0.001000, ResNet50: 0.001000
# Step 24: planet_18 Error = 24.65, resnet_18 Error = 34.76, resnet_50 Error = 34.13
# Step 48: planet_18 Error = 23.67, resnet_18 Error = 34.19, resnet_50 Error = 34.93
# Step 72: planet_18 Error = 25.31, resnet_18 Error = 34.79, resnet_50 Error = 32.05
# Step 96: planet_18 Error = 24.84, resnet_18 Error = 34.48, resnet_50 Error = 33.30
# Step 120: planet_18 Error = 27.03, resnet_18 Error = 34.52, resnet_50 Error = 33.13
# Step 144: planet_18 Error = 23.64, resnet_18 Error = 33.99, resnet_50 Error = 32.64
# Planet18 last avg_loss_planet_18 : 0.5645429082214832, Resnet18 last avg_loss_resnet_18 : 0.8348888978362083, Resnet50 last avg_loss_resnet_50 : 0.8400995954871178
#
# Epoch 13/50
# Current LR - Planet18: 0.000100, ResNet18: 0.001000, ResNet50: 0.001000
# Step 24: planet_18 Error = 23.26, resnet_18 Error = 32.86, resnet_50 Error = 30.72
# Step 48: planet_18 Error = 22.58, resnet_18 Error = 32.64, resnet_50 Error = 31.28
# Step 72: planet_18 Error = 23.04, resnet_18 Error = 32.21, resnet_50 Error = 31.60
# Step 96: planet_18 Error = 23.20, resnet_18 Error = 31.51, resnet_50 Error = 31.65
# Step 120: planet_18 Error = 24.49, resnet_18 Error = 32.01, resnet_50 Error = 34.77
# Step 144: planet_18 Error = 22.97, resnet_18 Error = 32.10, resnet_50 Error = 30.92
# Planet18 last avg_loss_planet_18 : 0.5830597095191479, Resnet18 last avg_loss_resnet_18 : 0.9178716391324997, Resnet50 last avg_loss_resnet_50 : 0.8946434333920479
#
# Epoch 14/50
# Current LR - Planet18: 0.000100, ResNet18: 0.001000, ResNet50: 0.001000
# Step 24: planet_18 Error = 22.07, resnet_18 Error = 32.11, resnet_50 Error = 31.63
# Step 48: planet_18 Error = 22.72, resnet_18 Error = 30.93, resnet_50 Error = 31.54
# Step 72: planet_18 Error = 23.37, resnet_18 Error = 30.82, resnet_50 Error = 29.45
# Step 96: planet_18 Error = 21.94, resnet_18 Error = 28.36, resnet_50 Error = 28.43
# Step 120: planet_18 Error = 22.39, resnet_18 Error = 28.98, resnet_50 Error = 31.92
# Step 144: planet_18 Error = 22.92, resnet_18 Error = 29.02, resnet_50 Error = 31.06
# Planet18 last avg_loss_planet_18 : 0.5225833430886269, Resnet18 last avg_loss_resnet_18 : 0.8183736875653267, Resnet50 last avg_loss_resnet_50 : 0.8027539774775505
#
# Epoch 15/50
# Current LR - Planet18: 0.000100, ResNet18: 0.001000, ResNet50: 0.001000
# Step 24: planet_18 Error = 22.02, resnet_18 Error = 29.30, resnet_50 Error = 30.68
# Step 48: planet_18 Error = 21.68, resnet_18 Error = 28.65, resnet_50 Error = 28.12
# Step 72: planet_18 Error = 20.97, resnet_18 Error = 28.77, resnet_50 Error = 29.75
# Step 96: planet_18 Error = 21.28, resnet_18 Error = 29.77, resnet_50 Error = 28.04
# Step 120: planet_18 Error = 20.60, resnet_18 Error = 27.22, resnet_50 Error = 29.22
# Step 144: planet_18 Error = 21.63, resnet_18 Error = 28.75, resnet_50 Error = 27.90
# Planet18 last avg_loss_planet_18 : 0.5300614535808563, Resnet18 last avg_loss_resnet_18 : 0.7065728008747101, Resnet50 last avg_loss_resnet_50 : 0.7909102439880371
#
# Epoch 16/50
# Current LR - Planet18: 0.000100, ResNet18: 0.001000, ResNet50: 0.001000
# Step 24: planet_18 Error = 20.68, resnet_18 Error = 28.25, resnet_50 Error = 28.61
# Step 48: planet_18 Error = 22.05, resnet_18 Error = 27.79, resnet_50 Error = 27.02
# Step 72: planet_18 Error = 20.44, resnet_18 Error = 26.03, resnet_50 Error = 26.87
# Step 96: planet_18 Error = 20.57, resnet_18 Error = 27.10, resnet_50 Error = 27.04
# Step 120: planet_18 Error = 20.53, resnet_18 Error = 27.10, resnet_50 Error = 27.07
# Step 144: planet_18 Error = 21.91, resnet_18 Error = 26.88, resnet_50 Error = 27.87
# Planet18 last avg_loss_planet_18 : 0.4184936583042145, Resnet18 last avg_loss_resnet_18 : 0.6234209053218365, Resnet50 last avg_loss_resnet_50 : 0.6620838828384876
#
# Epoch 17/50
# Current LR - Planet18: 0.000100, ResNet18: 0.001000, ResNet50: 0.001000
# Step 24: planet_18 Error = 21.18, resnet_18 Error = 25.36, resnet_50 Error = 29.85
# Step 48: planet_18 Error = 23.08, resnet_18 Error = 24.58, resnet_50 Error = 27.06
# Step 72: planet_18 Error = 22.26, resnet_18 Error = 23.98, resnet_50 Error = 26.33
# Step 96: planet_18 Error = 20.25, resnet_18 Error = 25.58, resnet_50 Error = 27.76
# Step 120: planet_18 Error = 21.61, resnet_18 Error = 25.56, resnet_50 Error = 28.08
# Step 144: planet_18 Error = 19.96, resnet_18 Error = 24.73, resnet_50 Error = 26.17
# Planet18 last avg_loss_planet_18 : 0.5104843750596046, Resnet18 last avg_loss_resnet_18 : 0.6566990315914154, Resnet50 last avg_loss_resnet_50 : 0.6785169020295143
#
# Epoch 18/50
# Current LR - Planet18: 0.000100, ResNet18: 0.001000, ResNet50: 0.001000
# Step 24: planet_18 Error = 20.29, resnet_18 Error = 25.65, resnet_50 Error = 26.95
# Step 48: planet_18 Error = 19.91, resnet_18 Error = 23.99, resnet_50 Error = 26.46
# Step 72: planet_18 Error = 20.33, resnet_18 Error = 24.46, resnet_50 Error = 26.47
# Step 96: planet_18 Error = 20.25, resnet_18 Error = 25.08, resnet_50 Error = 26.28
# Step 120: planet_18 Error = 20.72, resnet_18 Error = 24.00, resnet_50 Error = 25.34
# Step 144: planet_18 Error = 19.03, resnet_18 Error = 23.32, resnet_50 Error = 24.30
# Planet18 last avg_loss_planet_18 : 0.4690043739974499, Resnet18 last avg_loss_resnet_18 : 0.6526796743273735, Resnet50 last avg_loss_resnet_50 : 0.6399712227284908
#
# Epoch 19/50
# Current LR - Planet18: 0.000100, ResNet18: 0.001000, ResNet50: 0.001000
# Step 24: planet_18 Error = 18.69, resnet_18 Error = 23.15, resnet_50 Error = 25.88
# Step 48: planet_18 Error = 18.67, resnet_18 Error = 24.29, resnet_50 Error = 24.11
# Step 72: planet_18 Error = 19.33, resnet_18 Error = 22.48, resnet_50 Error = 24.01
# Step 96: planet_18 Error = 20.13, resnet_18 Error = 23.91, resnet_50 Error = 25.70
# Step 120: planet_18 Error = 20.40, resnet_18 Error = 23.88, resnet_50 Error = 24.21
# Step 144: planet_18 Error = 19.23, resnet_18 Error = 23.02, resnet_50 Error = 25.54
# Planet18 last avg_loss_planet_18 : 0.4698580726981163, Resnet18 last avg_loss_resnet_18 : 0.6267940551042557, Resnet50 last avg_loss_resnet_50 : 0.5984385646879673
#
# Epoch 20/50
# Current LR - Planet18: 0.000100, ResNet18: 0.001000, ResNet50: 0.001000
# Step 24: planet_18 Error = 19.02, resnet_18 Error = 22.62, resnet_50 Error = 26.80
# Step 48: planet_18 Error = 19.02, resnet_18 Error = 22.51, resnet_50 Error = 24.05
# Step 72: planet_18 Error = 18.94, resnet_18 Error = 22.33, resnet_50 Error = 24.71
# Step 96: planet_18 Error = 19.28, resnet_18 Error = 22.61, resnet_50 Error = 24.47
# Step 120: planet_18 Error = 19.54, resnet_18 Error = 22.39, resnet_50 Error = 22.48
# Step 144: planet_18 Error = 20.23, resnet_18 Error = 21.35, resnet_50 Error = 23.28
# Planet18 last avg_loss_planet_18 : 0.4317151829600334, Resnet18 last avg_loss_resnet_18 : 0.5087768584489822, Resnet50 last avg_loss_resnet_50 : 0.6426190324127674
#
# Epoch 21/50
# Current LR - Planet18: 0.000100, ResNet18: 0.001000, ResNet50: 0.001000
# Step 24: planet_18 Error = 19.00, resnet_18 Error = 21.56, resnet_50 Error = 23.14
# Step 48: planet_18 Error = 19.98, resnet_18 Error = 22.20, resnet_50 Error = 24.75
# Step 72: planet_18 Error = 20.15, resnet_18 Error = 22.74, resnet_50 Error = 23.44
# Step 96: planet_18 Error = 18.65, resnet_18 Error = 21.37, resnet_50 Error = 23.16
# Step 120: planet_18 Error = 19.55, resnet_18 Error = 22.23, resnet_50 Error = 24.55
# Step 144: planet_18 Error = 19.61, resnet_18 Error = 21.72, resnet_50 Error = 23.12
# Planet18 last avg_loss_planet_18 : 0.37540216371417046, Resnet18 last avg_loss_resnet_18 : 0.5650588683784008, Resnet50 last avg_loss_resnet_50 : 0.6250895038247108
#
# Epoch 22/50
# Current LR - Planet18: 0.000100, ResNet18: 0.001000, ResNet50: 0.001000
# Step 24: planet_18 Error = 19.48, resnet_18 Error = 21.12, resnet_50 Error = 23.43
# Step 48: planet_18 Error = 18.64, resnet_18 Error = 20.78, resnet_50 Error = 22.69
# Step 72: planet_18 Error = 18.92, resnet_18 Error = 21.76, resnet_50 Error = 24.09
# Step 96: planet_18 Error = 19.02, resnet_18 Error = 21.59, resnet_50 Error = 22.46
# Step 120: planet_18 Error = 17.99, resnet_18 Error = 22.63, resnet_50 Error = 24.99
# Step 144: planet_18 Error = 18.27, resnet_18 Error = 20.44, resnet_50 Error = 22.44
# Planet18 last avg_loss_planet_18 : 0.3708397466689348, Resnet18 last avg_loss_resnet_18 : 0.46009381860494614, Resnet50 last avg_loss_resnet_50 : 0.41572481393814087
#
# Epoch 23/50
# Current LR - Planet18: 0.000100, ResNet18: 0.001000, ResNet50: 0.001000
# Step 24: planet_18 Error = 18.31, resnet_18 Error = 20.05, resnet_50 Error = 21.36
# Step 48: planet_18 Error = 18.50, resnet_18 Error = 20.52, resnet_50 Error = 21.41
# Step 72: planet_18 Error = 18.09, resnet_18 Error = 19.88, resnet_50 Error = 22.46
# Step 96: planet_18 Error = 18.56, resnet_18 Error = 20.24, resnet_50 Error = 21.98
# Step 120: planet_18 Error = 18.84, resnet_18 Error = 19.95, resnet_50 Error = 21.29
# Step 144: planet_18 Error = 18.24, resnet_18 Error = 19.87, resnet_50 Error = 22.51
# Planet18 last avg_loss_planet_18 : 0.34378165751695633, Resnet18 last avg_loss_resnet_18 : 0.3936389423906803, Resnet50 last avg_loss_resnet_50 : 0.4473187290132046
#
# Epoch 24/50
# Current LR - Planet18: 0.000100, ResNet18: 0.001000, ResNet50: 0.001000
# Step 24: planet_18 Error = 17.37, resnet_18 Error = 19.37, resnet_50 Error = 21.06
# Step 48: planet_18 Error = 18.09, resnet_18 Error = 19.75, resnet_50 Error = 21.52
# Step 72: planet_18 Error = 18.37, resnet_18 Error = 20.15, resnet_50 Error = 21.79
# Step 96: planet_18 Error = 17.73, resnet_18 Error = 21.20, resnet_50 Error = 20.46
# Step 120: planet_18 Error = 17.78, resnet_18 Error = 19.13, resnet_50 Error = 21.65
# Step 144: planet_18 Error = 17.72, resnet_18 Error = 20.99, resnet_50 Error = 21.77
# Planet18 last avg_loss_planet_18 : 0.38344449549913406, Resnet18 last avg_loss_resnet_18 : 0.4228287786245346, Resnet50 last avg_loss_resnet_50 : 0.5633702054619789
#
# Epoch 25/50
# Current LR - Planet18: 0.000100, ResNet18: 0.001000, ResNet50: 0.001000
# Step 24: planet_18 Error = 17.17, resnet_18 Error = 19.56, resnet_50 Error = 19.80
# Step 48: planet_18 Error = 17.01, resnet_18 Error = 19.06, resnet_50 Error = 20.17
# Step 72: planet_18 Error = 18.48, resnet_18 Error = 19.85, resnet_50 Error = 20.76
# Step 96: planet_18 Error = 17.09, resnet_18 Error = 19.50, resnet_50 Error = 21.28
# Step 120: planet_18 Error = 17.24, resnet_18 Error = 19.19, resnet_50 Error = 20.35
# Step 144: planet_18 Error = 17.48, resnet_18 Error = 19.20, resnet_50 Error = 19.84
# Planet18 last avg_loss_planet_18 : 0.4216254651546478, Resnet18 last avg_loss_resnet_18 : 0.4034922271966934, Resnet50 last avg_loss_resnet_50 : 0.5891258642077446
#
# Epoch 26/50
# Current LR - Planet18: 0.000100, ResNet18: 0.001000, ResNet50: 0.001000
# Step 24: planet_18 Error = 16.81, resnet_18 Error = 19.71, resnet_50 Error = 22.02
# Step 48: planet_18 Error = 17.41, resnet_18 Error = 19.49, resnet_50 Error = 19.78
# Step 72: planet_18 Error = 17.48, resnet_18 Error = 21.20, resnet_50 Error = 19.70
# Step 96: planet_18 Error = 17.02, resnet_18 Error = 18.79, resnet_50 Error = 20.04
# Step 120: planet_18 Error = 16.47, resnet_18 Error = 19.31, resnet_50 Error = 19.40
# Step 144: planet_18 Error = 18.19, resnet_18 Error = 18.20, resnet_50 Error = 20.47
# Planet18 last avg_loss_planet_18 : 0.41848256811499596, Resnet18 last avg_loss_resnet_18 : 0.47181810811161995, Resnet50 last avg_loss_resnet_50 : 0.5483666025102139
#
# Epoch 27/50
# Current LR - Planet18: 0.000100, ResNet18: 0.001000, ResNet50: 0.001000
# Step 24: planet_18 Error = 16.60, resnet_18 Error = 18.14, resnet_50 Error = 19.27
# Step 48: planet_18 Error = 17.45, resnet_18 Error = 18.37, resnet_50 Error = 18.77
# Step 72: planet_18 Error = 18.31, resnet_18 Error = 18.85, resnet_50 Error = 20.05
# Step 96: planet_18 Error = 16.94, resnet_18 Error = 19.58, resnet_50 Error = 19.77
# Step 120: planet_18 Error = 16.79, resnet_18 Error = 18.25, resnet_50 Error = 19.47
# Step 144: planet_18 Error = 16.98, resnet_18 Error = 20.87, resnet_50 Error = 19.53
# Planet18 last avg_loss_planet_18 : 0.36030866391956806, Resnet18 last avg_loss_resnet_18 : 0.4996948055922985, Resnet50 last avg_loss_resnet_50 : 0.4424436539411545
#
# Epoch 28/50
# Current LR - Planet18: 0.000100, ResNet18: 0.001000, ResNet50: 0.001000
# Step 24: planet_18 Error = 18.55, resnet_18 Error = 18.27, resnet_50 Error = 20.47
# Step 48: planet_18 Error = 16.02, resnet_18 Error = 19.31, resnet_50 Error = 20.52
# Step 72: planet_18 Error = 16.70, resnet_18 Error = 17.99, resnet_50 Error = 19.16
# Step 96: planet_18 Error = 17.36, resnet_18 Error = 18.65, resnet_50 Error = 20.22
# Step 120: planet_18 Error = 17.14, resnet_18 Error = 18.40, resnet_50 Error = 18.74
# Step 144: planet_18 Error = 16.03, resnet_18 Error = 17.94, resnet_50 Error = 19.55
# Planet18 last avg_loss_planet_18 : 0.2912482814863324, Resnet18 last avg_loss_resnet_18 : 0.3957342756912112, Resnet50 last avg_loss_resnet_50 : 0.37361421808600426
#
# Epoch 29/50
# Current LR - Planet18: 0.000100, ResNet18: 0.001000, ResNet50: 0.001000
# Step 24: planet_18 Error = 16.95, resnet_18 Error = 18.60, resnet_50 Error = 18.43
# Step 48: planet_18 Error = 16.36, resnet_18 Error = 18.16, resnet_50 Error = 18.08
# Step 72: planet_18 Error = 16.60, resnet_18 Error = 17.86, resnet_50 Error = 18.32
# Step 96: planet_18 Error = 16.39, resnet_18 Error = 18.46, resnet_50 Error = 18.83
# Step 120: planet_18 Error = 16.52, resnet_18 Error = 18.26, resnet_50 Error = 18.63
# Step 144: planet_18 Error = 16.95, resnet_18 Error = 17.96, resnet_50 Error = 18.61
# Planet18 last avg_loss_planet_18 : 0.29133104532957077, Resnet18 last avg_loss_resnet_18 : 0.4323958791792393, Resnet50 last avg_loss_resnet_50 : 0.4468514621257782
#
# Epoch 30/50
# Current LR - Planet18: 0.000100, ResNet18: 0.001000, ResNet50: 0.001000
# Step 24: planet_18 Error = 16.16, resnet_18 Error = 17.15, resnet_50 Error = 20.14
# Step 48: planet_18 Error = 16.50, resnet_18 Error = 17.90, resnet_50 Error = 19.94
# Step 72: planet_18 Error = 16.51, resnet_18 Error = 18.44, resnet_50 Error = 18.29
# Step 96: planet_18 Error = 17.00, resnet_18 Error = 16.87, resnet_50 Error = 18.62
# Step 120: planet_18 Error = 16.49, resnet_18 Error = 16.59, resnet_50 Error = 18.49
# Step 144: planet_18 Error = 16.87, resnet_18 Error = 17.60, resnet_50 Error = 17.62
# Planet18 last avg_loss_planet_18 : 0.28103975765407085, Resnet18 last avg_loss_resnet_18 : 0.4050578959286213, Resnet50 last avg_loss_resnet_50 : 0.5544616058468819
#
# Epoch 31/50
# Current LR - Planet18: 0.000100, ResNet18: 0.001000, ResNet50: 0.001000
# Step 24: planet_18 Error = 15.89, resnet_18 Error = 16.82, resnet_50 Error = 18.77
# Step 48: planet_18 Error = 16.93, resnet_18 Error = 18.71, resnet_50 Error = 17.42
# Step 72: planet_18 Error = 16.45, resnet_18 Error = 17.11, resnet_50 Error = 17.97
# Step 96: planet_18 Error = 16.21, resnet_18 Error = 16.93, resnet_50 Error = 16.94
# Step 120: planet_18 Error = 16.13, resnet_18 Error = 16.64, resnet_50 Error = 19.00
# Step 144: planet_18 Error = 16.64, resnet_18 Error = 16.69, resnet_50 Error = 17.61
# Planet18 last avg_loss_planet_18 : 0.2805282073095441, Resnet18 last avg_loss_resnet_18 : 0.34056099131703377, Resnet50 last avg_loss_resnet_50 : 0.3488894049078226
#
# Epoch 32/50
# Current LR - Planet18: 0.000100, ResNet18: 0.001000, ResNet50: 0.001000
# Step 24: planet_18 Error = 16.23, resnet_18 Error = 16.93, resnet_50 Error = 18.97
# Step 48: planet_18 Error = 16.01, resnet_18 Error = 16.76, resnet_50 Error = 18.55
# Step 72: planet_18 Error = 16.48, resnet_18 Error = 17.60, resnet_50 Error = 18.67
# Step 96: planet_18 Error = 16.19, resnet_18 Error = 19.40, resnet_50 Error = 19.15
# Step 120: planet_18 Error = 16.45, resnet_18 Error = 16.83, resnet_50 Error = 17.07
# Step 144: planet_18 Error = 16.83, resnet_18 Error = 16.91, resnet_50 Error = 18.74
# Planet18 last avg_loss_planet_18 : 0.38534499146044254, Resnet18 last avg_loss_resnet_18 : 0.3138792235404253, Resnet50 last avg_loss_resnet_50 : 0.37137473933398724
#
# Epoch 33/50
# Current LR - Planet18: 0.000100, ResNet18: 0.001000, ResNet50: 0.001000
# Step 24: planet_18 Error = 16.31, resnet_18 Error = 17.09, resnet_50 Error = 18.16
# Step 48: planet_18 Error = 16.81, resnet_18 Error = 16.56, resnet_50 Error = 18.13
# Step 72: planet_18 Error = 18.58, resnet_18 Error = 16.91, resnet_50 Error = 18.75
# Step 96: planet_18 Error = 15.43, resnet_18 Error = 16.15, resnet_50 Error = 17.36
# Step 120: planet_18 Error = 16.15, resnet_18 Error = 16.72, resnet_50 Error = 18.19
# Step 144: planet_18 Error = 16.25, resnet_18 Error = 15.81, resnet_50 Error = 18.46
# Planet18 last avg_loss_planet_18 : 0.3025146722793579, Resnet18 last avg_loss_resnet_18 : 0.3359291646629572, Resnet50 last avg_loss_resnet_50 : 0.4173797722905874
#
# Epoch 34/50
# Current LR - Planet18: 0.000100, ResNet18: 0.001000, ResNet50: 0.001000
# Step 24: planet_18 Error = 17.03, resnet_18 Error = 16.85, resnet_50 Error = 18.28
# Step 48: planet_18 Error = 15.54, resnet_18 Error = 17.71, resnet_50 Error = 17.11
# Step 72: planet_18 Error = 16.15, resnet_18 Error = 16.76, resnet_50 Error = 17.26
# Step 96: planet_18 Error = 15.86, resnet_18 Error = 16.30, resnet_50 Error = 17.20
# Step 120: planet_18 Error = 17.14, resnet_18 Error = 16.83, resnet_50 Error = 17.19
# Step 144: planet_18 Error = 15.77, resnet_18 Error = 16.47, resnet_50 Error = 17.53
# Planet18 last avg_loss_planet_18 : 0.25476210936903954, Resnet18 last avg_loss_resnet_18 : 0.27540328726172447, Resnet50 last avg_loss_resnet_50 : 0.3500890005379915
#
# Epoch 35/50
# Current LR - Planet18: 0.000100, ResNet18: 0.001000, ResNet50: 0.001000
# Step 24: planet_18 Error = 15.03, resnet_18 Error = 16.70, resnet_50 Error = 16.66
# Step 48: planet_18 Error = 16.68, resnet_18 Error = 16.67, resnet_50 Error = 18.08
# Step 72: planet_18 Error = 15.36, resnet_18 Error = 16.33, resnet_50 Error = 18.54
# Step 96: planet_18 Error = 15.97, resnet_18 Error = 16.03, resnet_50 Error = 17.62
# Step 120: planet_18 Error = 15.75, resnet_18 Error = 15.48, resnet_50 Error = 17.22
# Step 144: planet_18 Error = 15.38, resnet_18 Error = 17.38, resnet_50 Error = 17.12
# Planet18 last avg_loss_planet_18 : 0.20459713879972696, Resnet18 last avg_loss_resnet_18 : 0.31767237931489944, Resnet50 last avg_loss_resnet_50 : 0.34181617945432663
#
# Epoch 36/50
# Current LR - Planet18: 0.000100, ResNet18: 0.001000, ResNet50: 0.001000
# Step 24: planet_18 Error = 16.60, resnet_18 Error = 16.71, resnet_50 Error = 16.97
# Step 48: planet_18 Error = 16.33, resnet_18 Error = 16.35, resnet_50 Error = 17.70
# Step 72: planet_18 Error = 15.31, resnet_18 Error = 15.83, resnet_50 Error = 16.40
# Step 96: planet_18 Error = 15.27, resnet_18 Error = 15.86, resnet_50 Error = 17.66
# Step 120: planet_18 Error = 15.89, resnet_18 Error = 15.96, resnet_50 Error = 17.88
# Step 144: planet_18 Error = 16.01, resnet_18 Error = 15.81, resnet_50 Error = 19.10
# Planet18 last avg_loss_planet_18 : 0.2110681664198637, Resnet18 last avg_loss_resnet_18 : 0.24125776160508394, Resnet50 last avg_loss_resnet_50 : 0.3536322247236967
#
# Epoch 37/50
# Current LR - Planet18: 0.000100, ResNet18: 0.001000, ResNet50: 0.001000
# Step 24: planet_18 Error = 15.30, resnet_18 Error = 16.14, resnet_50 Error = 16.43
# Step 48: planet_18 Error = 16.55, resnet_18 Error = 16.93, resnet_50 Error = 17.02
# Step 72: planet_18 Error = 15.72, resnet_18 Error = 17.06, resnet_50 Error = 17.57
# Step 96: planet_18 Error = 16.29, resnet_18 Error = 15.55, resnet_50 Error = 16.42
# Step 120: planet_18 Error = 15.67, resnet_18 Error = 15.75, resnet_50 Error = 16.10
# Step 144: planet_18 Error = 15.67, resnet_18 Error = 16.01, resnet_50 Error = 16.11
# Planet18 last avg_loss_planet_18 : 0.2016585972160101, Resnet18 last avg_loss_resnet_18 : 0.2672315528616309, Resnet50 last avg_loss_resnet_50 : 0.2519395314157009
#
# Epoch 38/50
# Current LR - Planet18: 0.000100, ResNet18: 0.001000, ResNet50: 0.001000
# Step 24: planet_18 Error = 14.99, resnet_18 Error = 15.78, resnet_50 Error = 17.42
# Step 48: planet_18 Error = 16.30, resnet_18 Error = 17.03, resnet_50 Error = 17.91
# Step 72: planet_18 Error = 16.29, resnet_18 Error = 16.66, resnet_50 Error = 16.93
# Step 96: planet_18 Error = 14.97, resnet_18 Error = 15.69, resnet_50 Error = 17.08
# Step 120: planet_18 Error = 15.56, resnet_18 Error = 15.79, resnet_50 Error = 15.95
# Step 144: planet_18 Error = 15.57, resnet_18 Error = 16.23, resnet_50 Error = 17.94
# Planet18 last avg_loss_planet_18 : 0.30138825811445713, Resnet18 last avg_loss_resnet_18 : 0.2731813583523035, Resnet50 last avg_loss_resnet_50 : 0.2906592097133398
#
# Epoch 39/50
# Current LR - Planet18: 0.000100, ResNet18: 0.001000, ResNet50: 0.001000
# Step 24: planet_18 Error = 15.99, resnet_18 Error = 15.45, resnet_50 Error = 17.13
# Step 48: planet_18 Error = 14.68, resnet_18 Error = 16.15, resnet_50 Error = 17.30
# Step 72: planet_18 Error = 14.78, resnet_18 Error = 17.62, resnet_50 Error = 16.60
# Step 96: planet_18 Error = 16.17, resnet_18 Error = 15.46, resnet_50 Error = 16.41
# Step 120: planet_18 Error = 15.42, resnet_18 Error = 15.83, resnet_50 Error = 15.70
# Step 144: planet_18 Error = 15.23, resnet_18 Error = 15.37, resnet_50 Error = 16.57
# Planet18 last avg_loss_planet_18 : 0.19927552063018084, Resnet18 last avg_loss_resnet_18 : 0.2082803975790739, Resnet50 last avg_loss_resnet_50 : 0.245169835165143
#
# Epoch 40/50
# Current LR - Planet18: 0.000100, ResNet18: 0.001000, ResNet50: 0.001000
# Step 24: planet_18 Error = 15.35, resnet_18 Error = 15.17, resnet_50 Error = 16.15
# Step 48: planet_18 Error = 15.55, resnet_18 Error = 16.83, resnet_50 Error = 17.17
# Step 72: planet_18 Error = 15.43, resnet_18 Error = 15.99, resnet_50 Error = 16.39
# Step 96: planet_18 Error = 15.88, resnet_18 Error = 16.11, resnet_50 Error = 15.86
# Step 120: planet_18 Error = 15.33, resnet_18 Error = 15.79, resnet_50 Error = 16.09
# Step 144: planet_18 Error = 16.26, resnet_18 Error = 15.66, resnet_50 Error = 16.12
# Planet18 last avg_loss_planet_18 : 0.2197089735418558, Resnet18 last avg_loss_resnet_18 : 0.29497932177037, Resnet50 last avg_loss_resnet_50 : 0.2821780052036047
#
# Epoch 41/50
# Current LR - Planet18: 0.000100, ResNet18: 0.001000, ResNet50: 0.001000
# Step 24: planet_18 Error = 15.50, resnet_18 Error = 15.96, resnet_50 Error = 15.92
# Step 48: planet_18 Error = 15.00, resnet_18 Error = 15.16, resnet_50 Error = 16.09
# Step 72: planet_18 Error = 14.87, resnet_18 Error = 15.68, resnet_50 Error = 17.54
# Step 96: planet_18 Error = 15.20, resnet_18 Error = 15.55, resnet_50 Error = 15.19
# Step 120: planet_18 Error = 15.83, resnet_18 Error = 15.87, resnet_50 Error = 15.68
# Step 144: planet_18 Error = 15.63, resnet_18 Error = 15.48, resnet_50 Error = 17.07
# Planet18 last avg_loss_planet_18 : 0.2750436600763351, Resnet18 last avg_loss_resnet_18 : 0.35139999352395535, Resnet50 last avg_loss_resnet_50 : 0.24694943707436323
#
# Epoch 42/50
# Current LR - Planet18: 0.000100, ResNet18: 0.001000, ResNet50: 0.001000
# Step 24: planet_18 Error = 14.65, resnet_18 Error = 16.35, resnet_50 Error = 16.87
# Step 48: planet_18 Error = 14.94, resnet_18 Error = 15.67, resnet_50 Error = 16.60
# Step 72: planet_18 Error = 16.29, resnet_18 Error = 15.50, resnet_50 Error = 15.65
# Step 96: planet_18 Error = 15.11, resnet_18 Error = 16.23, resnet_50 Error = 15.36
# Step 120: planet_18 Error = 15.84, resnet_18 Error = 15.85, resnet_50 Error = 16.42
# Step 144: planet_18 Error = 15.58, resnet_18 Error = 16.02, resnet_50 Error = 15.45
# Planet18 last avg_loss_planet_18 : 0.13097898429259658, Resnet18 last avg_loss_resnet_18 : 0.16354335471987724, Resnet50 last avg_loss_resnet_50 : 0.1907353550195694
#
# Epoch 43/50
# Current LR - Planet18: 0.000100, ResNet18: 0.001000, ResNet50: 0.001000
# Step 24: planet_18 Error = 14.82, resnet_18 Error = 15.58, resnet_50 Error = 16.17
# Step 48: planet_18 Error = 15.18, resnet_18 Error = 15.15, resnet_50 Error = 15.72
# Step 72: planet_18 Error = 14.61, resnet_18 Error = 15.57, resnet_50 Error = 16.29
# Step 96: planet_18 Error = 14.91, resnet_18 Error = 14.51, resnet_50 Error = 15.20
# Step 120: planet_18 Error = 14.84, resnet_18 Error = 15.23, resnet_50 Error = 15.53
# Step 144: planet_18 Error = 15.37, resnet_18 Error = 15.44, resnet_50 Error = 15.39
# Planet18 last avg_loss_planet_18 : 0.1793100037612021, Resnet18 last avg_loss_resnet_18 : 0.26461520604789257, Resnet50 last avg_loss_resnet_50 : 0.36425331607460976
#
# Epoch 44/50
# Current LR - Planet18: 0.000100, ResNet18: 0.001000, ResNet50: 0.001000
# Step 24: planet_18 Error = 14.85, resnet_18 Error = 14.29, resnet_50 Error = 15.51
# Step 48: planet_18 Error = 14.98, resnet_18 Error = 15.88, resnet_50 Error = 17.19
# Step 72: planet_18 Error = 15.13, resnet_18 Error = 14.93, resnet_50 Error = 16.99
# Step 96: planet_18 Error = 14.91, resnet_18 Error = 15.01, resnet_50 Error = 15.83
# Step 120: planet_18 Error = 15.55, resnet_18 Error = 15.19, resnet_50 Error = 17.24
# Step 144: planet_18 Error = 15.14, resnet_18 Error = 15.74, resnet_50 Error = 16.93
# Planet18 last avg_loss_planet_18 : 0.212394536472857, Resnet18 last avg_loss_resnet_18 : 0.23155650682747364, Resnet50 last avg_loss_resnet_50 : 0.2647631987929344
#
# Epoch 45/50
# Current LR - Planet18: 0.000100, ResNet18: 0.001000, ResNet50: 0.001000
# Step 24: planet_18 Error = 15.18, resnet_18 Error = 14.24, resnet_50 Error = 15.27
# Step 48: planet_18 Error = 15.31, resnet_18 Error = 15.56, resnet_50 Error = 15.28
# Step 72: planet_18 Error = 15.50, resnet_18 Error = 14.77, resnet_50 Error = 15.63
# Step 96: planet_18 Error = 14.60, resnet_18 Error = 14.87, resnet_50 Error = 15.98
# Step 120: planet_18 Error = 15.36, resnet_18 Error = 15.30, resnet_50 Error = 15.19
# Step 144: planet_18 Error = 15.25, resnet_18 Error = 14.85, resnet_50 Error = 16.81
# Planet18 last avg_loss_planet_18 : 0.20762227941304445, Resnet18 last avg_loss_resnet_18 : 0.1958094360306859, Resnet50 last avg_loss_resnet_50 : 0.23991807736456394
#
# Epoch 46/50
# Current LR - Planet18: 0.000100, ResNet18: 0.001000, ResNet50: 0.001000
# Step 24: planet_18 Error = 14.53, resnet_18 Error = 15.06, resnet_50 Error = 15.62
# Step 48: planet_18 Error = 15.50, resnet_18 Error = 15.24, resnet_50 Error = 15.45
# Step 72: planet_18 Error = 14.88, resnet_18 Error = 14.93, resnet_50 Error = 15.59
# Step 96: planet_18 Error = 14.68, resnet_18 Error = 15.58, resnet_50 Error = 14.94
# Step 120: planet_18 Error = 14.88, resnet_18 Error = 15.47, resnet_50 Error = 15.23
# Step 144: planet_18 Error = 15.80, resnet_18 Error = 15.60, resnet_50 Error = 15.86
# Planet18 last avg_loss_planet_18 : 0.16671444661915302, Resnet18 last avg_loss_resnet_18 : 0.18068767664954066, Resnet50 last avg_loss_resnet_50 : 0.24356878362596035
#
# Epoch 47/50
# Current LR - Planet18: 0.000100, ResNet18: 0.001000, ResNet50: 0.001000
# Step 24: planet_18 Error = 14.73, resnet_18 Error = 15.65, resnet_50 Error = 17.08
# Step 48: planet_18 Error = 14.79, resnet_18 Error = 14.67, resnet_50 Error = 15.19
# Step 72: planet_18 Error = 14.92, resnet_18 Error = 14.51, resnet_50 Error = 15.92
# Step 96: planet_18 Error = 14.98, resnet_18 Error = 14.98, resnet_50 Error = 15.81
# Step 120: planet_18 Error = 14.66, resnet_18 Error = 14.71, resnet_50 Error = 14.63
# Step 144: planet_18 Error = 14.45, resnet_18 Error = 15.42, resnet_50 Error = 15.44
# Planet18 last avg_loss_planet_18 : 0.1641344390809536, Resnet18 last avg_loss_resnet_18 : 0.21937362477183342, Resnet50 last avg_loss_resnet_50 : 0.22777598164975643
#
# Epoch 48/50
# Current LR - Planet18: 0.000100, ResNet18: 0.001000, ResNet50: 0.001000
# Step 24: planet_18 Error = 15.04, resnet_18 Error = 14.65, resnet_50 Error = 14.51
# Step 48: planet_18 Error = 15.42, resnet_18 Error = 14.92, resnet_50 Error = 15.81
# Step 72: planet_18 Error = 15.07, resnet_18 Error = 16.03, resnet_50 Error = 15.97
# Step 96: planet_18 Error = 15.34, resnet_18 Error = 15.09, resnet_50 Error = 15.65
# Step 120: planet_18 Error = 14.78, resnet_18 Error = 14.38, resnet_50 Error = 14.80
# Step 144: planet_18 Error = 14.37, resnet_18 Error = 14.82, resnet_50 Error = 14.87
# Planet18 last avg_loss_planet_18 : 0.18998425267636776, Resnet18 last avg_loss_resnet_18 : 0.2813588660210371, Resnet50 last avg_loss_resnet_50 : 0.23912310786545277
#
# Epoch 49/50
# Current LR - Planet18: 0.000100, ResNet18: 0.001000, ResNet50: 0.001000
# Step 24: planet_18 Error = 14.99, resnet_18 Error = 14.61, resnet_50 Error = 15.02
# Step 48: planet_18 Error = 15.63, resnet_18 Error = 14.72, resnet_50 Error = 16.31
# Step 72: planet_18 Error = 14.91, resnet_18 Error = 15.54, resnet_50 Error = 15.28
# Step 96: planet_18 Error = 14.17, resnet_18 Error = 14.59, resnet_50 Error = 15.05
# Step 120: planet_18 Error = 15.18, resnet_18 Error = 13.50, resnet_50 Error = 16.64
# Step 144: planet_18 Error = 14.26, resnet_18 Error = 14.68, resnet_50 Error = 15.05
# Planet18 last avg_loss_planet_18 : 0.16346925124526024, Resnet18 last avg_loss_resnet_18 : 0.1550517911091447, Resnet50 last avg_loss_resnet_50 : 0.19621175527572632
#
# Epoch 50/50
# Current LR - Planet18: 0.000100, ResNet18: 0.001000, ResNet50: 0.001000
# Step 24: planet_18 Error = 15.42, resnet_18 Error = 15.41, resnet_50 Error = 14.81
# Step 48: planet_18 Error = 15.47, resnet_18 Error = 14.99, resnet_50 Error = 14.77
# Step 72: planet_18 Error = 14.70, resnet_18 Error = 15.06, resnet_50 Error = 14.53
# Step 96: planet_18 Error = 14.84, resnet_18 Error = 14.26, resnet_50 Error = 15.72
# Step 120: planet_18 Error = 15.10, resnet_18 Error = 14.37, resnet_50 Error = 15.14
# Step 144: planet_18 Error = 15.23, resnet_18 Error = 14.22, resnet_50 Error = 15.77
# Planet18 last avg_loss_planet_18 : 0.1212403210811317, Resnet18 last avg_loss_resnet_18 : 0.15829836716875434, Resnet50 last avg_loss_resnet_50 : 0.21413762774318457

# %%
# scheduler 확인
print(f"Planet18 scheduler: {planet_18_scheduler.get_last_lr()}")
print(f"Resnet18 scheduler: {resnet_18_scheduler.get_last_lr()}")
print(f"Resnet50 scheduler: {resnet_50_scheduler.get_last_lr()}")

# 몇 번 bad epoch인지 확인
print(f"Planet18 scheduler: {planet_18_scheduler.num_bad_epochs}")
print(f"Resnet18 scheduler: {resnet_18_scheduler.num_bad_epochs}")
print(f"Resnet50 scheduler: {resnet_50_scheduler.num_bad_epochs}")
# Out:
# Planet18 scheduler: [0.0001]
# Resnet18 scheduler: [0.001]
# Resnet50 scheduler: [0.001]
# Planet18 scheduler: 1
# Resnet18 scheduler: 0
# Resnet50 scheduler: 2

# %%
# 모델 저장 (중간 결과 보존)
torch.save(planet_18.state_dict(), 'planet_18_scheduler_epoch50.pth')
torch.save(resnet_18.state_dict(), 'resnet_18_scheduler_epoch50.pth')
torch.save(resnet_50.state_dict(), 'resnet_50_scheduler_epoch50.pth')

# %%
# epoch 51 ~ 100
for epoch in range(num_epochs):
    running_loss_planet_18 = 0.0
    running_loss_resnet_18 = 0.0
    running_loss_resnet_50 = 0.0

    accumulated_steps = batch_size // sub_batch_size # 누적 배치 크기
    
    print(f"\nEpoch {epoch + 51}/{num_epochs+50}")
    print(f"Current LR - Planet18: {planet_18_optimizer.param_groups[0]['lr']:.6f}, ResNet18: {resnet_18_optimizer.param_groups[0]['lr']:.6f}, ResNet50: {resnet_50_optimizer.param_groups[0]['lr']:.6f}")
    
    for i, data in enumerate(train_loader, 0):
        inputs, labels = data
        inputs = inputs.to(device)  # GPU로 이동
        labels = labels.to(device)  # GPU로 이동

        # 순전파 + 역전파 + 최적화
        outputs_planet_18 = planet_18(inputs)
        outputs_resnet_18 = resnet_18(inputs)
        outputs_resnet_50 = resnet_50(inputs)

        loss_planet_18 = criterion(outputs_planet_18, labels)
        loss_resnet_18 = criterion(outputs_resnet_18, labels)
        loss_resnet_50 = criterion(outputs_resnet_50, labels)

        loss_planet_18.backward()
        loss_resnet_18.backward()
        loss_resnet_50.backward()

        # 배치 손실 합계 계산
        running_loss_planet_18 += loss_planet_18.item()
        running_loss_resnet_18 += loss_resnet_18.item()
        running_loss_resnet_50 += loss_resnet_50.item()
        
        # 8번마다 파라미터 업데이트(256/32 = 8) -> gradient 누적
        if (i + 1) % accumulated_steps == 0:

            ## planet_18
            planet_18_optimizer.step() # 파라미터 업데이트
            planet_18_optimizer.zero_grad() # 변화도(gradient) 초기화
            
            ## resnet_18
            resnet_18_optimizer.step() # 파라미터 업데이트
            resnet_18_optimizer.zero_grad() # 변화도(gradient) 초기화

            ## resnet_50
            resnet_50_optimizer.step() # 파라미터 업데이트
            resnet_50_optimizer.zero_grad() # 변화도(gradient) 초기화

            # 매번 손실 기록 (8번의 배치 평균)
            avg_loss_planet_18 = running_loss_planet_18 / accumulated_steps
            planet_18_loss.append(avg_loss_planet_18)

            avg_loss_resnet_18 = running_loss_resnet_18 / accumulated_steps
            resnet_18_loss.append(avg_loss_resnet_18)

            avg_loss_resnet_50 = running_loss_resnet_50 / accumulated_steps
            resnet_50_loss.append(avg_loss_resnet_50)

            # print(f"Step {i // accumulated_steps + 1}: planet_18 Loss = {avg_loss_planet_18:.4f}, resnet_18 Loss = {avg_loss_resnet_18:.4f}, resnet_50 Loss = {avg_loss_resnet_50:.4f}")

            # step 24마다 검증 데이터 평가
            if (i // accumulated_steps + 1) % 24 == 0:    
                val_error_planet_18 = evaluate_model(planet_18, val_loader)
                val_error_resnet_18 = evaluate_model(resnet_18, val_loader)
                val_error_resnet_50 = evaluate_model(resnet_50, val_loader)

                planet_18_error.append(val_error_planet_18)
                resnet_18_error.append(val_error_resnet_18)
                resnet_50_error.append(val_error_resnet_50)

                print(f"Step {i // accumulated_steps + 1}: planet_18 Error = {val_error_planet_18:.2f}, resnet_18 Error = {val_error_resnet_18:.2f}, resnet_50 Error = {val_error_resnet_50:.2f}")
                
            # running_loss 초기화 (다음 8번의 배치를 위해)
            running_loss_planet_18 = 0.0
            running_loss_resnet_18 = 0.0
            running_loss_resnet_50 = 0.0

    # 학습 루프가 끝난 후, 남은 그래디언트 처리
    if (len(train_loader) % accumulated_steps) != 0:
        planet_18_optimizer.step()
        planet_18_optimizer.zero_grad()

        resnet_18_optimizer.step()  
        resnet_18_optimizer.zero_grad()

        resnet_50_optimizer.step()
        resnet_50_optimizer.zero_grad()
    
    # 에포크 끝에서 스케줄러 업데이트 (검증 오류율 기준)
    if len(planet_18_error) > 0:
        # 경사 폭발 확인
        print(f"Planet18 last avg_loss_planet_18 : {avg_loss_planet_18}, Resnet18 last avg_loss_resnet_18 : {avg_loss_resnet_18}, Resnet50 last avg_loss_resnet_50 : {avg_loss_resnet_50}")

        # 몇 번 bad epoch인지 확인
        print(f"Planet18 scheduler: {planet_18_scheduler.num_bad_epochs}, Resnet18 scheduler: {resnet_18_scheduler.num_bad_epochs}, Resnet50 scheduler: {resnet_50_scheduler.num_bad_epochs}")


        planet_18_scheduler.step(planet_18_error[-1])
        resnet_18_scheduler.step(resnet_18_error[-1])
        resnet_50_scheduler.step(resnet_50_error[-1])
# Out:
# Epoch 51/100
# Current LR - Planet18: 0.000100, ResNet18: 0.001000, ResNet50: 0.001000
# Step 24: planet_18 Error = 14.40, resnet_18 Error = 14.15, resnet_50 Error = 14.61
# Step 48: planet_18 Error = 14.52, resnet_18 Error = 14.68, resnet_50 Error = 14.67
# Step 72: planet_18 Error = 15.44, resnet_18 Error = 14.47, resnet_50 Error = 14.79
# Step 96: planet_18 Error = 15.38, resnet_18 Error = 14.38, resnet_50 Error = 15.75
# Step 120: planet_18 Error = 15.04, resnet_18 Error = 14.66, resnet_50 Error = 15.34
# Step 144: planet_18 Error = 15.01, resnet_18 Error = 14.41, resnet_50 Error = 15.63
# Planet18 last avg_loss_planet_18 : 0.15379343554377556, Resnet18 last avg_loss_resnet_18 : 0.1912130513228476, Resnet50 last avg_loss_resnet_50 : 0.27285568602383137
# Planet18 scheduler: 1, Resnet18 scheduler: 0, Resnet50 scheduler: 2
#
# Epoch 52/100
# Current LR - Planet18: 0.000100, ResNet18: 0.001000, ResNet50: 0.001000
# Step 24: planet_18 Error = 14.67, resnet_18 Error = 13.92, resnet_50 Error = 14.79
# Step 48: planet_18 Error = 13.93, resnet_18 Error = 14.27, resnet_50 Error = 15.97
# Step 72: planet_18 Error = 15.13, resnet_18 Error = 13.81, resnet_50 Error = 14.65
# Step 96: planet_18 Error = 14.34, resnet_18 Error = 14.23, resnet_50 Error = 14.46
# Step 120: planet_18 Error = 14.52, resnet_18 Error = 14.11, resnet_50 Error = 15.64
# Step 144: planet_18 Error = 14.90, resnet_18 Error = 14.18, resnet_50 Error = 15.10
# Planet18 last avg_loss_planet_18 : 0.10284192115068436, Resnet18 last avg_loss_resnet_18 : 0.15197834465652704, Resnet50 last avg_loss_resnet_50 : 0.2185349566861987
# Planet18 scheduler: 2, Resnet18 scheduler: 1, Resnet50 scheduler: 3
#
# Epoch 53/100
# Current LR - Planet18: 0.000100, ResNet18: 0.001000, ResNet50: 0.001000
# Step 24: planet_18 Error = 14.96, resnet_18 Error = 14.31, resnet_50 Error = 15.62
# Step 48: planet_18 Error = 14.89, resnet_18 Error = 14.26, resnet_50 Error = 14.99
# Step 72: planet_18 Error = 14.84, resnet_18 Error = 14.33, resnet_50 Error = 14.30
# Step 96: planet_18 Error = 14.73, resnet_18 Error = 14.22, resnet_50 Error = 15.22
# Step 120: planet_18 Error = 14.87, resnet_18 Error = 14.00, resnet_50 Error = 14.29
# Step 144: planet_18 Error = 14.65, resnet_18 Error = 15.29, resnet_50 Error = 14.60
# Planet18 last avg_loss_planet_18 : 0.07110769534483552, Resnet18 last avg_loss_resnet_18 : 0.17210916196927428, Resnet50 last avg_loss_resnet_50 : 0.13285622838884592
# Planet18 scheduler: 3, Resnet18 scheduler: 0, Resnet50 scheduler: 4
#
# Epoch 54/100
# Current LR - Planet18: 0.000100, ResNet18: 0.001000, ResNet50: 0.001000
# Step 24: planet_18 Error = 14.73, resnet_18 Error = 14.67, resnet_50 Error = 15.60
# Step 48: planet_18 Error = 14.39, resnet_18 Error = 14.71, resnet_50 Error = 14.61
# Step 72: planet_18 Error = 14.59, resnet_18 Error = 14.95, resnet_50 Error = 15.71
# Step 96: planet_18 Error = 14.38, resnet_18 Error = 14.80, resnet_50 Error = 14.79
# Step 120: planet_18 Error = 14.82, resnet_18 Error = 14.17, resnet_50 Error = 15.12
# Step 144: planet_18 Error = 14.35, resnet_18 Error = 13.86, resnet_50 Error = 14.20
# Planet18 last avg_loss_planet_18 : 0.1567713082768023, Resnet18 last avg_loss_resnet_18 : 0.1455238270573318, Resnet50 last avg_loss_resnet_50 : 0.16749617829918861
# Planet18 scheduler: 4, Resnet18 scheduler: 1, Resnet50 scheduler: 0
#
# Epoch 55/100
# Current LR - Planet18: 0.000100, ResNet18: 0.001000, ResNet50: 0.001000
# Step 24: planet_18 Error = 14.30, resnet_18 Error = 14.44, resnet_50 Error = 14.52
# Step 48: planet_18 Error = 14.88, resnet_18 Error = 14.14, resnet_50 Error = 14.49
# Step 72: planet_18 Error = 14.28, resnet_18 Error = 14.75, resnet_50 Error = 15.35
# Step 96: planet_18 Error = 14.67, resnet_18 Error = 14.59, resnet_50 Error = 14.51
# Step 120: planet_18 Error = 14.38, resnet_18 Error = 14.07, resnet_50 Error = 15.42
# Step 144: planet_18 Error = 14.73, resnet_18 Error = 14.86, resnet_50 Error = 14.96
# Planet18 last avg_loss_planet_18 : 0.15533244889229536, Resnet18 last avg_loss_resnet_18 : 0.16264452785253525, Resnet50 last avg_loss_resnet_50 : 0.24367518723011017
# Planet18 scheduler: 5, Resnet18 scheduler: 0, Resnet50 scheduler: 0
#
# Epoch 56/100
# Current LR - Planet18: 0.000010, ResNet18: 0.001000, ResNet50: 0.001000
# Step 24: planet_18 Error = 13.77, resnet_18 Error = 13.79, resnet_50 Error = 15.46
# Step 48: planet_18 Error = 13.67, resnet_18 Error = 13.36, resnet_50 Error = 14.49
# Step 72: planet_18 Error = 13.43, resnet_18 Error = 15.18, resnet_50 Error = 14.33
# Step 96: planet_18 Error = 12.91, resnet_18 Error = 14.47, resnet_50 Error = 15.36
# Step 120: planet_18 Error = 13.21, resnet_18 Error = 14.26, resnet_50 Error = 14.63
# Step 144: planet_18 Error = 12.72, resnet_18 Error = 14.77, resnet_50 Error = 14.86
# Planet18 last avg_loss_planet_18 : 0.04491418169345707, Resnet18 last avg_loss_resnet_18 : 0.13098258525133133, Resnet50 last avg_loss_resnet_50 : 0.2776895072311163
# Planet18 scheduler: 0, Resnet18 scheduler: 1, Resnet50 scheduler: 1
#
# Epoch 57/100
# Current LR - Planet18: 0.000010, ResNet18: 0.001000, ResNet50: 0.001000
# Step 24: planet_18 Error = 12.85, resnet_18 Error = 14.30, resnet_50 Error = 14.38
# Step 48: planet_18 Error = 12.78, resnet_18 Error = 14.24, resnet_50 Error = 14.25
# Step 72: planet_18 Error = 12.35, resnet_18 Error = 14.59, resnet_50 Error = 13.75
# Step 96: planet_18 Error = 12.84, resnet_18 Error = 14.39, resnet_50 Error = 14.61
# Step 120: planet_18 Error = 13.02, resnet_18 Error = 13.67, resnet_50 Error = 14.69
# Step 144: planet_18 Error = 12.92, resnet_18 Error = 14.25, resnet_50 Error = 15.16
# Planet18 last avg_loss_planet_18 : 0.05274246959015727, Resnet18 last avg_loss_resnet_18 : 0.1475043226382695, Resnet50 last avg_loss_resnet_50 : 0.25268737645819783
# Planet18 scheduler: 0, Resnet18 scheduler: 2, Resnet50 scheduler: 2
#
# Epoch 58/100
# Current LR - Planet18: 0.000010, ResNet18: 0.001000, ResNet50: 0.001000
# Step 24: planet_18 Error = 13.01, resnet_18 Error = 13.98, resnet_50 Error = 14.49
# Step 48: planet_18 Error = 13.11, resnet_18 Error = 14.92, resnet_50 Error = 14.16
# Step 72: planet_18 Error = 13.21, resnet_18 Error = 14.67, resnet_50 Error = 14.13
# Step 96: planet_18 Error = 12.84, resnet_18 Error = 14.06, resnet_50 Error = 14.85
# Step 120: planet_18 Error = 12.76, resnet_18 Error = 14.19, resnet_50 Error = 15.32
# Step 144: planet_18 Error = 12.53, resnet_18 Error = 13.59, resnet_50 Error = 14.31
# Planet18 last avg_loss_planet_18 : 0.052525798440910876, Resnet18 last avg_loss_resnet_18 : 0.15433648461475968, Resnet50 last avg_loss_resnet_50 : 0.16059727128595114
# Planet18 scheduler: 1, Resnet18 scheduler: 3, Resnet50 scheduler: 3
#
# Epoch 59/100
# Current LR - Planet18: 0.000010, ResNet18: 0.001000, ResNet50: 0.001000
# Step 24: planet_18 Error = 12.56, resnet_18 Error = 13.84, resnet_50 Error = 13.98
# Step 48: planet_18 Error = 12.69, resnet_18 Error = 13.92, resnet_50 Error = 13.70
# Step 72: planet_18 Error = 13.58, resnet_18 Error = 13.99, resnet_50 Error = 14.46
# Step 96: planet_18 Error = 12.56, resnet_18 Error = 14.24, resnet_50 Error = 15.34
# Step 120: planet_18 Error = 12.77, resnet_18 Error = 15.26, resnet_50 Error = 15.14
# Step 144: planet_18 Error = 12.72, resnet_18 Error = 14.07, resnet_50 Error = 14.29
# Planet18 last avg_loss_planet_18 : 0.07581928872969002, Resnet18 last avg_loss_resnet_18 : 0.15064753545448184, Resnet50 last avg_loss_resnet_50 : 0.14229121059179306
# Planet18 scheduler: 0, Resnet18 scheduler: 0, Resnet50 scheduler: 4
#
# Epoch 60/100
# Current LR - Planet18: 0.000010, ResNet18: 0.001000, ResNet50: 0.001000
# Step 24: planet_18 Error = 12.38, resnet_18 Error = 14.12, resnet_50 Error = 14.81
# Step 48: planet_18 Error = 13.27, resnet_18 Error = 14.09, resnet_50 Error = 16.06
# Step 72: planet_18 Error = 12.68, resnet_18 Error = 14.20, resnet_50 Error = 14.21
# Step 96: planet_18 Error = 12.45, resnet_18 Error = 13.98, resnet_50 Error = 13.99
# Step 120: planet_18 Error = 12.71, resnet_18 Error = 14.11, resnet_50 Error = 14.46
# Step 144: planet_18 Error = 12.97, resnet_18 Error = 14.22, resnet_50 Error = 14.28
# Planet18 last avg_loss_planet_18 : 0.0415859465720132, Resnet18 last avg_loss_resnet_18 : 0.10727708134800196, Resnet50 last avg_loss_resnet_50 : 0.19595785113051534
# Planet18 scheduler: 1, Resnet18 scheduler: 1, Resnet50 scheduler: 5
#
# Epoch 61/100
# Current LR - Planet18: 0.000010, ResNet18: 0.001000, ResNet50: 0.000100
# Step 24: planet_18 Error = 12.88, resnet_18 Error = 14.32, resnet_50 Error = 13.23
# Step 48: planet_18 Error = 12.58, resnet_18 Error = 13.59, resnet_50 Error = 12.93
# Step 72: planet_18 Error = 12.58, resnet_18 Error = 14.07, resnet_50 Error = 12.47
# Step 96: planet_18 Error = 12.56, resnet_18 Error = 14.24, resnet_50 Error = 12.65
# Step 120: planet_18 Error = 12.53, resnet_18 Error = 14.10, resnet_50 Error = 12.58
# Step 144: planet_18 Error = 13.07, resnet_18 Error = 15.08, resnet_50 Error = 12.59
# Planet18 last avg_loss_planet_18 : 0.029328991193324327, Resnet18 last avg_loss_resnet_18 : 0.1179113294929266, Resnet50 last avg_loss_resnet_50 : 0.0726746792497579
# Planet18 scheduler: 2, Resnet18 scheduler: 2, Resnet50 scheduler: 0
#
# Epoch 62/100
# Current LR - Planet18: 0.000010, ResNet18: 0.001000, ResNet50: 0.000100
# Step 24: planet_18 Error = 12.80, resnet_18 Error = 14.56, resnet_50 Error = 12.15
# Step 48: planet_18 Error = 12.64, resnet_18 Error = 13.99, resnet_50 Error = 12.34
# Step 72: planet_18 Error = 12.49, resnet_18 Error = 14.55, resnet_50 Error = 12.60
# Step 96: planet_18 Error = 12.72, resnet_18 Error = 13.81, resnet_50 Error = 12.20
# Step 120: planet_18 Error = 12.98, resnet_18 Error = 13.84, resnet_50 Error = 12.14
# Step 144: planet_18 Error = 12.71, resnet_18 Error = 13.81, resnet_50 Error = 11.99
# Planet18 last avg_loss_planet_18 : 0.019909658789401874, Resnet18 last avg_loss_resnet_18 : 0.1328168883919716, Resnet50 last avg_loss_resnet_50 : 0.06363369198516011
# Planet18 scheduler: 3, Resnet18 scheduler: 3, Resnet50 scheduler: 0
#
# Epoch 63/100
# Current LR - Planet18: 0.000010, ResNet18: 0.001000, ResNet50: 0.000100
# Step 24: planet_18 Error = 12.77, resnet_18 Error = 13.45, resnet_50 Error = 11.96
# Step 48: planet_18 Error = 12.80, resnet_18 Error = 13.86, resnet_50 Error = 12.44
# Step 72: planet_18 Error = 12.60, resnet_18 Error = 14.16, resnet_50 Error = 12.46
# Step 96: planet_18 Error = 12.87, resnet_18 Error = 14.02, resnet_50 Error = 12.08
# Step 120: planet_18 Error = 12.71, resnet_18 Error = 13.73, resnet_50 Error = 12.26
# Step 144: planet_18 Error = 12.72, resnet_18 Error = 13.65, resnet_50 Error = 12.06
# Planet18 last avg_loss_planet_18 : 0.03219971538055688, Resnet18 last avg_loss_resnet_18 : 0.12232444761320949, Resnet50 last avg_loss_resnet_50 : 0.055425656493753195
# Planet18 scheduler: 4, Resnet18 scheduler: 4, Resnet50 scheduler: 0
#
# Epoch 64/100
# Current LR - Planet18: 0.000010, ResNet18: 0.001000, ResNet50: 0.000100
# Step 24: planet_18 Error = 12.55, resnet_18 Error = 13.93, resnet_50 Error = 11.83
# Step 48: planet_18 Error = 12.80, resnet_18 Error = 13.76, resnet_50 Error = 12.43
# Step 72: planet_18 Error = 12.74, resnet_18 Error = 13.72, resnet_50 Error = 12.22
# Step 96: planet_18 Error = 12.83, resnet_18 Error = 13.58, resnet_50 Error = 12.24
# Step 120: planet_18 Error = 12.92, resnet_18 Error = 13.53, resnet_50 Error = 12.21
# Step 144: planet_18 Error = 12.54, resnet_18 Error = 13.76, resnet_50 Error = 11.93
# Planet18 last avg_loss_planet_18 : 0.06776817385980394, Resnet18 last avg_loss_resnet_18 : 0.11405170522630215, Resnet50 last avg_loss_resnet_50 : 0.05082004953874275
# Planet18 scheduler: 5, Resnet18 scheduler: 5, Resnet50 scheduler: 1
#
# Epoch 65/100
# Current LR - Planet18: 0.000001, ResNet18: 0.000100, ResNet50: 0.000100
# Step 24: planet_18 Error = 12.72, resnet_18 Error = 13.09, resnet_50 Error = 11.83
# Step 48: planet_18 Error = 12.45, resnet_18 Error = 12.53, resnet_50 Error = 12.34
# Step 72: planet_18 Error = 12.73, resnet_18 Error = 12.21, resnet_50 Error = 12.51
# Step 96: planet_18 Error = 12.78, resnet_18 Error = 12.62, resnet_50 Error = 12.62
# Step 120: planet_18 Error = 12.89, resnet_18 Error = 12.50, resnet_50 Error = 12.06
# Step 144: planet_18 Error = 12.35, resnet_18 Error = 11.68, resnet_50 Error = 12.11
# Planet18 last avg_loss_planet_18 : 0.0638245885638753, Resnet18 last avg_loss_resnet_18 : 0.0804045987315476, Resnet50 last avg_loss_resnet_50 : 0.03804361046059057
# Planet18 scheduler: 0, Resnet18 scheduler: 0, Resnet50 scheduler: 0
#
# Epoch 66/100
# Current LR - Planet18: 0.000001, ResNet18: 0.000100, ResNet50: 0.000100
# Step 24: planet_18 Error = 12.88, resnet_18 Error = 12.25, resnet_50 Error = 12.20
# Step 48: planet_18 Error = 13.40, resnet_18 Error = 12.37, resnet_50 Error = 12.34
# Step 72: planet_18 Error = 12.34, resnet_18 Error = 12.16, resnet_50 Error = 12.19
# Step 96: planet_18 Error = 12.82, resnet_18 Error = 12.14, resnet_50 Error = 11.95
# Step 120: planet_18 Error = 12.45, resnet_18 Error = 12.34, resnet_50 Error = 12.04
# Step 144: planet_18 Error = 12.90, resnet_18 Error = 12.05, resnet_50 Error = 12.23
# Planet18 last avg_loss_planet_18 : 0.03528387632104568, Resnet18 last avg_loss_resnet_18 : 0.08978230180218816, Resnet50 last avg_loss_resnet_50 : 0.0755769441020675
# Planet18 scheduler: 0, Resnet18 scheduler: 0, Resnet50 scheduler: 1
#
# Epoch 67/100
# Current LR - Planet18: 0.000001, ResNet18: 0.000100, ResNet50: 0.000100
# Step 24: planet_18 Error = 12.19, resnet_18 Error = 12.47, resnet_50 Error = 12.05
# Step 48: planet_18 Error = 12.59, resnet_18 Error = 12.02, resnet_50 Error = 12.19
# Step 72: planet_18 Error = 12.73, resnet_18 Error = 12.10, resnet_50 Error = 12.12
# Step 96: planet_18 Error = 12.39, resnet_18 Error = 11.81, resnet_50 Error = 12.10
# Step 120: planet_18 Error = 12.49, resnet_18 Error = 11.79, resnet_50 Error = 12.57
# Step 144: planet_18 Error = 12.69, resnet_18 Error = 11.88, resnet_50 Error = 12.32
# Planet18 last avg_loss_planet_18 : 0.02285999004379846, Resnet18 last avg_loss_resnet_18 : 0.026980054681189358, Resnet50 last avg_loss_resnet_50 : 0.023753941131872125
# Planet18 scheduler: 1, Resnet18 scheduler: 1, Resnet50 scheduler: 2
#
# Epoch 68/100
# Current LR - Planet18: 0.000001, ResNet18: 0.000100, ResNet50: 0.000100
# Step 24: planet_18 Error = 12.81, resnet_18 Error = 12.06, resnet_50 Error = 12.23
# Step 48: planet_18 Error = 12.81, resnet_18 Error = 11.70, resnet_50 Error = 12.12
# Step 72: planet_18 Error = 12.59, resnet_18 Error = 11.87, resnet_50 Error = 12.13
# Step 96: planet_18 Error = 12.80, resnet_18 Error = 11.89, resnet_50 Error = 11.87
# Step 120: planet_18 Error = 12.06, resnet_18 Error = 11.98, resnet_50 Error = 12.22
# Step 144: planet_18 Error = 12.73, resnet_18 Error = 12.08, resnet_50 Error = 12.23
# Planet18 last avg_loss_planet_18 : 0.02505389188445406, Resnet18 last avg_loss_resnet_18 : 0.05427747798967175, Resnet50 last avg_loss_resnet_50 : 0.04249078285647556
# Planet18 scheduler: 2, Resnet18 scheduler: 2, Resnet50 scheduler: 3
#
# Epoch 69/100
# Current LR - Planet18: 0.000001, ResNet18: 0.000100, ResNet50: 0.000100
# Step 24: planet_18 Error = 12.75, resnet_18 Error = 12.09, resnet_50 Error = 12.28
# Step 48: planet_18 Error = 12.97, resnet_18 Error = 11.46, resnet_50 Error = 11.93
# Step 72: planet_18 Error = 12.65, resnet_18 Error = 11.78, resnet_50 Error = 12.00
# Step 96: planet_18 Error = 12.51, resnet_18 Error = 11.85, resnet_50 Error = 12.24
# Step 120: planet_18 Error = 13.06, resnet_18 Error = 11.87, resnet_50 Error = 12.00
# Step 144: planet_18 Error = 12.76, resnet_18 Error = 11.85, resnet_50 Error = 12.29
# Planet18 last avg_loss_planet_18 : 0.011653863264655229, Resnet18 last avg_loss_resnet_18 : 0.03511707091820426, Resnet50 last avg_loss_resnet_50 : 0.029173282004194334
# Planet18 scheduler: 3, Resnet18 scheduler: 3, Resnet50 scheduler: 4
#
# Epoch 70/100
# Current LR - Planet18: 0.000001, ResNet18: 0.000100, ResNet50: 0.000100
# Step 24: planet_18 Error = 12.53, resnet_18 Error = 11.64, resnet_50 Error = 12.25
# Step 48: planet_18 Error = 12.70, resnet_18 Error = 11.56, resnet_50 Error = 12.42
# Step 72: planet_18 Error = 12.45, resnet_18 Error = 11.82, resnet_50 Error = 12.29
# Step 96: planet_18 Error = 12.22, resnet_18 Error = 11.76, resnet_50 Error = 11.95
# Step 120: planet_18 Error = 12.81, resnet_18 Error = 11.92, resnet_50 Error = 12.71
# Step 144: planet_18 Error = 12.76, resnet_18 Error = 12.02, resnet_50 Error = 12.38
# Planet18 last avg_loss_planet_18 : 0.019260488523286767, Resnet18 last avg_loss_resnet_18 : 0.011407171885366552, Resnet50 last avg_loss_resnet_50 : 0.029015888343565166
# Planet18 scheduler: 4, Resnet18 scheduler: 4, Resnet50 scheduler: 5
#
# Epoch 71/100
# Current LR - Planet18: 0.000001, ResNet18: 0.000100, ResNet50: 0.000010
# Step 24: planet_18 Error = 12.32, resnet_18 Error = 12.06, resnet_50 Error = 11.96
# Step 48: planet_18 Error = 12.62, resnet_18 Error = 12.01, resnet_50 Error = 12.03
# Step 72: planet_18 Error = 12.63, resnet_18 Error = 12.38, resnet_50 Error = 11.70
# Step 96: planet_18 Error = 12.81, resnet_18 Error = 12.06, resnet_50 Error = 11.94
# Step 120: planet_18 Error = 12.35, resnet_18 Error = 11.79, resnet_50 Error = 12.11
# Step 144: planet_18 Error = 12.56, resnet_18 Error = 12.01, resnet_50 Error = 11.96
# Planet18 last avg_loss_planet_18 : 0.01121633214643225, Resnet18 last avg_loss_resnet_18 : 0.027169880475412356, Resnet50 last avg_loss_resnet_50 : 0.04310274985618889
# Planet18 scheduler: 5, Resnet18 scheduler: 5, Resnet50 scheduler: 0
#
# Epoch 72/100
# Current LR - Planet18: 0.000000, ResNet18: 0.000010, ResNet50: 0.000010
# Step 24: planet_18 Error = 12.52, resnet_18 Error = 12.31, resnet_50 Error = 11.89
# Step 48: planet_18 Error = 12.50, resnet_18 Error = 11.72, resnet_50 Error = 11.75
# Step 72: planet_18 Error = 12.76, resnet_18 Error = 11.60, resnet_50 Error = 11.79
# Step 96: planet_18 Error = 12.86, resnet_18 Error = 11.69, resnet_50 Error = 11.64
# Step 120: planet_18 Error = 12.00, resnet_18 Error = 12.06, resnet_50 Error = 11.87
# Step 144: planet_18 Error = 12.76, resnet_18 Error = 11.98, resnet_50 Error = 12.23
# Planet18 last avg_loss_planet_18 : 0.05027725217951229, Resnet18 last avg_loss_resnet_18 : 0.021125865838257596, Resnet50 last avg_loss_resnet_50 : 0.029039757675491273
# Planet18 scheduler: 0, Resnet18 scheduler: 0, Resnet50 scheduler: 1
#
# Epoch 73/100
# Current LR - Planet18: 0.000000, ResNet18: 0.000010, ResNet50: 0.000010
# Step 24: planet_18 Error = 12.87, resnet_18 Error = 11.75, resnet_50 Error = 11.98
# Step 48: planet_18 Error = 12.89, resnet_18 Error = 11.79, resnet_50 Error = 11.89
# Step 72: planet_18 Error = 12.72, resnet_18 Error = 11.44, resnet_50 Error = 12.20
# Step 96: planet_18 Error = 12.67, resnet_18 Error = 11.58, resnet_50 Error = 12.33
# Step 120: planet_18 Error = 12.44, resnet_18 Error = 11.57, resnet_50 Error = 12.21
# Step 144: planet_18 Error = 12.68, resnet_18 Error = 11.59, resnet_50 Error = 11.63
# Planet18 last avg_loss_planet_18 : 0.020633428444853052, Resnet18 last avg_loss_resnet_18 : 0.019149655345245264, Resnet50 last avg_loss_resnet_50 : 0.058919136732583866
# Planet18 scheduler: 1, Resnet18 scheduler: 1, Resnet50 scheduler: 2
#
# Epoch 74/100
# Current LR - Planet18: 0.000000, ResNet18: 0.000010, ResNet50: 0.000010
# Step 24: planet_18 Error = 12.55, resnet_18 Error = 11.99, resnet_50 Error = 12.07
# Step 48: planet_18 Error = 12.72, resnet_18 Error = 11.74, resnet_50 Error = 11.90
# Step 72: planet_18 Error = 12.89, resnet_18 Error = 11.52, resnet_50 Error = 12.16
# Step 96: planet_18 Error = 12.88, resnet_18 Error = 12.29, resnet_50 Error = 12.08
# Step 120: planet_18 Error = 12.42, resnet_18 Error = 11.86, resnet_50 Error = 11.79
# Step 144: planet_18 Error = 12.90, resnet_18 Error = 11.81, resnet_50 Error = 12.26
# Planet18 last avg_loss_planet_18 : 0.01505747833289206, Resnet18 last avg_loss_resnet_18 : 0.012394264398608357, Resnet50 last avg_loss_resnet_50 : 0.022107746510300785
# Planet18 scheduler: 2, Resnet18 scheduler: 0, Resnet50 scheduler: 0
#
# Epoch 75/100
# Current LR - Planet18: 0.000000, ResNet18: 0.000010, ResNet50: 0.000010
# Step 24: planet_18 Error = 12.78, resnet_18 Error = 11.64, resnet_50 Error = 12.29
# Step 48: planet_18 Error = 12.57, resnet_18 Error = 11.77, resnet_50 Error = 11.72
# Step 72: planet_18 Error = 12.58, resnet_18 Error = 11.79, resnet_50 Error = 11.88
# Step 96: planet_18 Error = 12.96, resnet_18 Error = 11.83, resnet_50 Error = 11.70
# Step 120: planet_18 Error = 12.73, resnet_18 Error = 11.79, resnet_50 Error = 12.08
# Step 144: planet_18 Error = 12.52, resnet_18 Error = 11.78, resnet_50 Error = 12.39
# Planet18 last avg_loss_planet_18 : 0.031209356238832697, Resnet18 last avg_loss_resnet_18 : 0.05873589147813618, Resnet50 last avg_loss_resnet_50 : 0.03287122258916497
# Planet18 scheduler: 3, Resnet18 scheduler: 1, Resnet50 scheduler: 1
#
# Epoch 76/100
# Current LR - Planet18: 0.000000, ResNet18: 0.000010, ResNet50: 0.000010
# Step 24: planet_18 Error = 12.56, resnet_18 Error = 12.16, resnet_50 Error = 11.76
# Step 48: planet_18 Error = 12.72, resnet_18 Error = 11.93, resnet_50 Error = 12.40
# Step 72: planet_18 Error = 12.38, resnet_18 Error = 11.60, resnet_50 Error = 11.99
# Step 96: planet_18 Error = 12.54, resnet_18 Error = 11.55, resnet_50 Error = 11.65
# Step 120: planet_18 Error = 12.53, resnet_18 Error = 11.78, resnet_50 Error = 12.16
# Step 144: planet_18 Error = 12.80, resnet_18 Error = 12.08, resnet_50 Error = 11.88
# Planet18 last avg_loss_planet_18 : 0.014891959603119176, Resnet18 last avg_loss_resnet_18 : 0.034827757539460436, Resnet50 last avg_loss_resnet_50 : 0.02496373181929812
# Planet18 scheduler: 4, Resnet18 scheduler: 2, Resnet50 scheduler: 2
#
# Epoch 77/100
# Current LR - Planet18: 0.000000, ResNet18: 0.000010, ResNet50: 0.000010
# Step 24: planet_18 Error = 12.69, resnet_18 Error = 11.46, resnet_50 Error = 11.74
# Step 48: planet_18 Error = 12.76, resnet_18 Error = 12.06, resnet_50 Error = 11.92
# Step 72: planet_18 Error = 12.55, resnet_18 Error = 11.73, resnet_50 Error = 11.82
# Step 96: planet_18 Error = 12.93, resnet_18 Error = 11.92, resnet_50 Error = 11.90
# Step 120: planet_18 Error = 12.94, resnet_18 Error = 11.78, resnet_50 Error = 11.99
# Step 144: planet_18 Error = 12.83, resnet_18 Error = 12.01, resnet_50 Error = 12.10
# Planet18 last avg_loss_planet_18 : 0.02133878186577931, Resnet18 last avg_loss_resnet_18 : 0.009868941648164764, Resnet50 last avg_loss_resnet_50 : 0.040620093313918915
# Planet18 scheduler: 5, Resnet18 scheduler: 3, Resnet50 scheduler: 3
#
# Epoch 78/100
# Current LR - Planet18: 0.000000, ResNet18: 0.000010, ResNet50: 0.000010
# Step 24: planet_18 Error = 12.65, resnet_18 Error = 11.82, resnet_50 Error = 11.95
# Step 48: planet_18 Error = 12.34, resnet_18 Error = 11.47, resnet_50 Error = 12.05
# Step 72: planet_18 Error = 12.32, resnet_18 Error = 11.40, resnet_50 Error = 12.00
# Step 96: planet_18 Error = 12.39, resnet_18 Error = 11.52, resnet_50 Error = 12.02
# Step 120: planet_18 Error = 12.79, resnet_18 Error = 11.79, resnet_50 Error = 11.66
# Step 144: planet_18 Error = 12.77, resnet_18 Error = 11.86, resnet_50 Error = 12.22
# Planet18 last avg_loss_planet_18 : 0.04383634828263894, Resnet18 last avg_loss_resnet_18 : 0.02800245222169906, Resnet50 last avg_loss_resnet_50 : 0.02532950058230199
# Planet18 scheduler: 0, Resnet18 scheduler: 4, Resnet50 scheduler: 4
#
# Epoch 79/100
# Current LR - Planet18: 0.000000, ResNet18: 0.000010, ResNet50: 0.000010
# Step 24: planet_18 Error = 12.58, resnet_18 Error = 11.91, resnet_50 Error = 12.08
# Step 48: planet_18 Error = 12.66, resnet_18 Error = 11.58, resnet_50 Error = 11.99
# Step 72: planet_18 Error = 12.74, resnet_18 Error = 11.94, resnet_50 Error = 12.02
# Step 96: planet_18 Error = 12.74, resnet_18 Error = 11.84, resnet_50 Error = 12.06
# Step 120: planet_18 Error = 12.60, resnet_18 Error = 11.80, resnet_50 Error = 11.66
# Step 144: planet_18 Error = 12.45, resnet_18 Error = 11.40, resnet_50 Error = 11.57
# Planet18 last avg_loss_planet_18 : 0.043063145771156996, Resnet18 last avg_loss_resnet_18 : 0.03380000469041988, Resnet50 last avg_loss_resnet_50 : 0.037890984676778316
# Planet18 scheduler: 1, Resnet18 scheduler: 5, Resnet50 scheduler: 5
#
# Epoch 80/100
# Current LR - Planet18: 0.000000, ResNet18: 0.000010, ResNet50: 0.000010
# Step 24: planet_18 Error = 12.72, resnet_18 Error = 11.69, resnet_50 Error = 12.21
# Step 48: planet_18 Error = 12.70, resnet_18 Error = 11.43, resnet_50 Error = 11.96
# Step 72: planet_18 Error = 12.53, resnet_18 Error = 11.70, resnet_50 Error = 11.66
# Step 96: planet_18 Error = 12.25, resnet_18 Error = 11.62, resnet_50 Error = 11.53
# Step 120: planet_18 Error = 12.51, resnet_18 Error = 11.31, resnet_50 Error = 11.79
# Step 144: planet_18 Error = 12.74, resnet_18 Error = 11.82, resnet_50 Error = 12.08
# Planet18 last avg_loss_planet_18 : 0.03776625001046341, Resnet18 last avg_loss_resnet_18 : 0.0146530525671551, Resnet50 last avg_loss_resnet_50 : 0.04135403627878986
# Planet18 scheduler: 2, Resnet18 scheduler: 0, Resnet50 scheduler: 0
#
# Epoch 81/100
# Current LR - Planet18: 0.000000, ResNet18: 0.000010, ResNet50: 0.000010
# Step 24: planet_18 Error = 12.54, resnet_18 Error = 11.57, resnet_50 Error = 12.07
# Step 48: planet_18 Error = 12.51, resnet_18 Error = 11.76, resnet_50 Error = 11.81
# Step 72: planet_18 Error = 12.77, resnet_18 Error = 11.75, resnet_50 Error = 12.03
# Step 96: planet_18 Error = 12.77, resnet_18 Error = 11.43, resnet_50 Error = 11.91
# Step 120: planet_18 Error = 12.70, resnet_18 Error = 11.60, resnet_50 Error = 12.27
# Step 144: planet_18 Error = 12.51, resnet_18 Error = 12.02, resnet_50 Error = 11.98
# Planet18 last avg_loss_planet_18 : 0.02986840525045409, Resnet18 last avg_loss_resnet_18 : 0.02994750184006989, Resnet50 last avg_loss_resnet_50 : 0.03502563574875239
# Planet18 scheduler: 3, Resnet18 scheduler: 1, Resnet50 scheduler: 1
#
# Epoch 82/100
# Current LR - Planet18: 0.000000, ResNet18: 0.000010, ResNet50: 0.000010
# Step 24: planet_18 Error = 12.83, resnet_18 Error = 11.86, resnet_50 Error = 11.75
# Step 48: planet_18 Error = 12.75, resnet_18 Error = 12.07, resnet_50 Error = 11.75
# Step 72: planet_18 Error = 12.46, resnet_18 Error = 11.53, resnet_50 Error = 11.76
# Step 96: planet_18 Error = 12.88, resnet_18 Error = 11.65, resnet_50 Error = 11.72
# Step 120: planet_18 Error = 12.70, resnet_18 Error = 11.51, resnet_50 Error = 11.70
# Step 144: planet_18 Error = 12.75, resnet_18 Error = 11.61, resnet_50 Error = 11.53
# Planet18 last avg_loss_planet_18 : 0.012839120929129422, Resnet18 last avg_loss_resnet_18 : 0.048699854873120785, Resnet50 last avg_loss_resnet_50 : 0.03791330743115395
# Planet18 scheduler: 4, Resnet18 scheduler: 2, Resnet50 scheduler: 2
#
# Epoch 83/100
# Current LR - Planet18: 0.000000, ResNet18: 0.000010, ResNet50: 0.000010
# Step 24: planet_18 Error = 12.67, resnet_18 Error = 11.59, resnet_50 Error = 12.12
# Step 48: planet_18 Error = 12.45, resnet_18 Error = 12.07, resnet_50 Error = 12.24
# Step 72: planet_18 Error = 12.42, resnet_18 Error = 11.51, resnet_50 Error = 12.01
# Step 96: planet_18 Error = 12.43, resnet_18 Error = 11.62, resnet_50 Error = 11.89
# Step 120: planet_18 Error = 12.84, resnet_18 Error = 11.78, resnet_50 Error = 11.70
# Step 144: planet_18 Error = 12.50, resnet_18 Error = 11.86, resnet_50 Error = 12.24
# Planet18 last avg_loss_planet_18 : 0.022211096686078236, Resnet18 last avg_loss_resnet_18 : 0.03249034746659163, Resnet50 last avg_loss_resnet_50 : 0.024882979807443917
# Planet18 scheduler: 5, Resnet18 scheduler: 3, Resnet50 scheduler: 0
#
# Epoch 84/100
# Current LR - Planet18: 0.000000, ResNet18: 0.000010, ResNet50: 0.000010
# Step 24: planet_18 Error = 12.34, resnet_18 Error = 11.80, resnet_50 Error = 11.94
# Step 48: planet_18 Error = 12.48, resnet_18 Error = 11.77, resnet_50 Error = 12.03
# Step 72: planet_18 Error = 12.93, resnet_18 Error = 11.43, resnet_50 Error = 11.63
# Step 96: planet_18 Error = 12.94, resnet_18 Error = 11.63, resnet_50 Error = 11.87
# Step 120: planet_18 Error = 12.35, resnet_18 Error = 11.66, resnet_50 Error = 11.86
# Step 144: planet_18 Error = 12.46, resnet_18 Error = 11.55, resnet_50 Error = 11.94
# Planet18 last avg_loss_planet_18 : 0.028627282634261064, Resnet18 last avg_loss_resnet_18 : 0.043586865067481995, Resnet50 last avg_loss_resnet_50 : 0.03379678295459598
# Planet18 scheduler: 0, Resnet18 scheduler: 4, Resnet50 scheduler: 1
#
# Epoch 85/100
# Current LR - Planet18: 0.000000, ResNet18: 0.000010, ResNet50: 0.000010
# Step 24: planet_18 Error = 12.64, resnet_18 Error = 12.00, resnet_50 Error = 11.83
# Step 48: planet_18 Error = 12.79, resnet_18 Error = 11.95, resnet_50 Error = 12.01
# Step 72: planet_18 Error = 12.74, resnet_18 Error = 11.79, resnet_50 Error = 11.99
# Step 96: planet_18 Error = 12.47, resnet_18 Error = 11.57, resnet_50 Error = 11.93
# Step 120: planet_18 Error = 12.66, resnet_18 Error = 12.01, resnet_50 Error = 12.00
# Step 144: planet_18 Error = 12.88, resnet_18 Error = 11.46, resnet_50 Error = 11.76
# Planet18 last avg_loss_planet_18 : 0.03441193437902257, Resnet18 last avg_loss_resnet_18 : 0.017180853144964203, Resnet50 last avg_loss_resnet_50 : 0.015306569713175122
# Planet18 scheduler: 1, Resnet18 scheduler: 5, Resnet50 scheduler: 2
#
# Epoch 86/100
# Current LR - Planet18: 0.000000, ResNet18: 0.000001, ResNet50: 0.000010
# Step 24: planet_18 Error = 12.45, resnet_18 Error = 12.00, resnet_50 Error = 11.75
# Step 48: planet_18 Error = 12.32, resnet_18 Error = 11.78, resnet_50 Error = 11.79
# Step 72: planet_18 Error = 12.52, resnet_18 Error = 11.38, resnet_50 Error = 11.92
# Step 96: planet_18 Error = 12.62, resnet_18 Error = 11.70, resnet_50 Error = 12.02
# Step 120: planet_18 Error = 12.39, resnet_18 Error = 11.43, resnet_50 Error = 12.08
# Step 144: planet_18 Error = 12.68, resnet_18 Error = 11.50, resnet_50 Error = 11.81
# Planet18 last avg_loss_planet_18 : 0.03816225682385266, Resnet18 last avg_loss_resnet_18 : 0.04692636162508279, Resnet50 last avg_loss_resnet_50 : 0.0365701622213237
# Planet18 scheduler: 2, Resnet18 scheduler: 0, Resnet50 scheduler: 3
#
# Epoch 87/100
# Current LR - Planet18: 0.000000, ResNet18: 0.000001, ResNet50: 0.000010
# Step 24: planet_18 Error = 12.53, resnet_18 Error = 11.84, resnet_50 Error = 12.18
# Step 48: planet_18 Error = 13.05, resnet_18 Error = 11.75, resnet_50 Error = 11.62
# Step 72: planet_18 Error = 12.93, resnet_18 Error = 11.75, resnet_50 Error = 11.94
# Step 96: planet_18 Error = 12.92, resnet_18 Error = 11.80, resnet_50 Error = 11.90
# Step 120: planet_18 Error = 12.53, resnet_18 Error = 12.27, resnet_50 Error = 11.89
# Step 144: planet_18 Error = 12.78, resnet_18 Error = 11.76, resnet_50 Error = 12.02
# Planet18 last avg_loss_planet_18 : 0.018612183805089444, Resnet18 last avg_loss_resnet_18 : 0.016500612735399045, Resnet50 last avg_loss_resnet_50 : 0.01445354858879
# Planet18 scheduler: 3, Resnet18 scheduler: 1, Resnet50 scheduler: 4
#
# Epoch 88/100
# Current LR - Planet18: 0.000000, ResNet18: 0.000001, ResNet50: 0.000010
# Step 24: planet_18 Error = 12.65, resnet_18 Error = 11.98, resnet_50 Error = 11.79
# Step 48: planet_18 Error = 12.38, resnet_18 Error = 11.60, resnet_50 Error = 12.34
# Step 72: planet_18 Error = 12.50, resnet_18 Error = 11.50, resnet_50 Error = 12.01
# Step 96: planet_18 Error = 12.30, resnet_18 Error = 11.76, resnet_50 Error = 12.05
# Step 120: planet_18 Error = 12.43, resnet_18 Error = 11.73, resnet_50 Error = 11.95
# Step 144: planet_18 Error = 12.85, resnet_18 Error = 11.44, resnet_50 Error = 12.04
# Planet18 last avg_loss_planet_18 : 0.010263488511554897, Resnet18 last avg_loss_resnet_18 : 0.01130821494734846, Resnet50 last avg_loss_resnet_50 : 0.050248284915141994
# Planet18 scheduler: 4, Resnet18 scheduler: 2, Resnet50 scheduler: 5
#
# Epoch 89/100
# Current LR - Planet18: 0.000000, ResNet18: 0.000001, ResNet50: 0.000001
# Step 24: planet_18 Error = 12.66, resnet_18 Error = 11.58, resnet_50 Error = 12.00
# Step 48: planet_18 Error = 12.45, resnet_18 Error = 11.69, resnet_50 Error = 12.06
# Step 72: planet_18 Error = 12.52, resnet_18 Error = 11.48, resnet_50 Error = 11.87
# Step 96: planet_18 Error = 12.73, resnet_18 Error = 11.85, resnet_50 Error = 12.00
# Step 120: planet_18 Error = 12.67, resnet_18 Error = 11.79, resnet_50 Error = 11.81
# Step 144: planet_18 Error = 12.71, resnet_18 Error = 11.80, resnet_50 Error = 11.95
# Planet18 last avg_loss_planet_18 : 0.011686625934089534, Resnet18 last avg_loss_resnet_18 : 0.027384479151805863, Resnet50 last avg_loss_resnet_50 : 0.03973366308491677
# Planet18 scheduler: 5, Resnet18 scheduler: 3, Resnet50 scheduler: 0
#
# Epoch 90/100
# Current LR - Planet18: 0.000000, ResNet18: 0.000001, ResNet50: 0.000001
# Step 24: planet_18 Error = 12.46, resnet_18 Error = 11.52, resnet_50 Error = 11.91
# Step 48: planet_18 Error = 12.74, resnet_18 Error = 11.70, resnet_50 Error = 12.55
# Step 72: planet_18 Error = 12.84, resnet_18 Error = 11.61, resnet_50 Error = 11.70
# Step 96: planet_18 Error = 12.86, resnet_18 Error = 11.95, resnet_50 Error = 12.15
# Step 120: planet_18 Error = 12.84, resnet_18 Error = 11.62, resnet_50 Error = 11.91
# Step 144: planet_18 Error = 12.40, resnet_18 Error = 11.74, resnet_50 Error = 12.19
# Planet18 last avg_loss_planet_18 : 0.016769066194683546, Resnet18 last avg_loss_resnet_18 : 0.020513073526672088, Resnet50 last avg_loss_resnet_50 : 0.0289939715876244
# Planet18 scheduler: 0, Resnet18 scheduler: 4, Resnet50 scheduler: 1
#
# Epoch 91/100
# Current LR - Planet18: 0.000000, ResNet18: 0.000001, ResNet50: 0.000001
# Step 24: planet_18 Error = 12.74, resnet_18 Error = 11.81, resnet_50 Error = 11.73
# Step 48: planet_18 Error = 12.75, resnet_18 Error = 11.50, resnet_50 Error = 11.97
# Step 72: planet_18 Error = 12.28, resnet_18 Error = 11.78, resnet_50 Error = 11.99
# Step 96: planet_18 Error = 12.39, resnet_18 Error = 11.73, resnet_50 Error = 11.85
# Step 120: planet_18 Error = 12.43, resnet_18 Error = 11.96, resnet_50 Error = 11.90
# Step 144: planet_18 Error = 12.56, resnet_18 Error = 11.57, resnet_50 Error = 11.85
# Planet18 last avg_loss_planet_18 : 0.022281189952991554, Resnet18 last avg_loss_resnet_18 : 0.007789906449033879, Resnet50 last avg_loss_resnet_50 : 0.02066441494753235
# Planet18 scheduler: 1, Resnet18 scheduler: 5, Resnet50 scheduler: 2
#
# Epoch 92/100
# Current LR - Planet18: 0.000000, ResNet18: 0.000000, ResNet50: 0.000001
# Step 24: planet_18 Error = 12.73, resnet_18 Error = 11.31, resnet_50 Error = 11.82
# Step 48: planet_18 Error = 12.34, resnet_18 Error = 11.89, resnet_50 Error = 11.68
# Step 72: planet_18 Error = 12.54, resnet_18 Error = 11.64, resnet_50 Error = 11.98
# Step 96: planet_18 Error = 12.49, resnet_18 Error = 11.59, resnet_50 Error = 12.44
# Step 120: planet_18 Error = 12.84, resnet_18 Error = 11.66, resnet_50 Error = 11.62
# Step 144: planet_18 Error = 12.63, resnet_18 Error = 11.95, resnet_50 Error = 11.78
# Planet18 last avg_loss_planet_18 : 0.01609356982226018, Resnet18 last avg_loss_resnet_18 : 0.012663323053857312, Resnet50 last avg_loss_resnet_50 : 0.044597507803700864
# Planet18 scheduler: 2, Resnet18 scheduler: 0, Resnet50 scheduler: 3
#
# Epoch 93/100
# Current LR - Planet18: 0.000000, ResNet18: 0.000000, ResNet50: 0.000001
# Step 24: planet_18 Error = 12.53, resnet_18 Error = 11.99, resnet_50 Error = 11.84
# Step 48: planet_18 Error = 12.83, resnet_18 Error = 11.85, resnet_50 Error = 11.77
# Step 72: planet_18 Error = 12.93, resnet_18 Error = 11.79, resnet_50 Error = 11.78
# Step 96: planet_18 Error = 12.58, resnet_18 Error = 11.74, resnet_50 Error = 11.89
# Step 120: planet_18 Error = 12.99, resnet_18 Error = 11.39, resnet_50 Error = 11.99
# Step 144: planet_18 Error = 12.41, resnet_18 Error = 11.87, resnet_50 Error = 11.80
# Planet18 last avg_loss_planet_18 : 0.05346122244372964, Resnet18 last avg_loss_resnet_18 : 0.013310314039699733, Resnet50 last avg_loss_resnet_50 : 0.03763939972850494
# Planet18 scheduler: 3, Resnet18 scheduler: 1, Resnet50 scheduler: 4
#
# Epoch 94/100
# Current LR - Planet18: 0.000000, ResNet18: 0.000000, ResNet50: 0.000001
# Step 24: planet_18 Error = 13.12, resnet_18 Error = 11.71, resnet_50 Error = 12.10
# Step 48: planet_18 Error = 12.18, resnet_18 Error = 11.80, resnet_50 Error = 12.14
# Step 72: planet_18 Error = 12.73, resnet_18 Error = 11.72, resnet_50 Error = 12.16
# Step 96: planet_18 Error = 12.83, resnet_18 Error = 11.60, resnet_50 Error = 12.01
# Step 120: planet_18 Error = 12.51, resnet_18 Error = 11.69, resnet_50 Error = 11.96
# Step 144: planet_18 Error = 12.78, resnet_18 Error = 11.91, resnet_50 Error = 12.31
# Planet18 last avg_loss_planet_18 : 0.011036802548915148, Resnet18 last avg_loss_resnet_18 : 0.037561042699962854, Resnet50 last avg_loss_resnet_50 : 0.015950074346619658
# Planet18 scheduler: 4, Resnet18 scheduler: 2, Resnet50 scheduler: 5
#
# Epoch 95/100
# Current LR - Planet18: 0.000000, ResNet18: 0.000000, ResNet50: 0.000000
# Step 24: planet_18 Error = 12.58, resnet_18 Error = 11.92, resnet_50 Error = 12.02
# Step 48: planet_18 Error = 12.93, resnet_18 Error = 11.70, resnet_50 Error = 12.20
# Step 72: planet_18 Error = 12.95, resnet_18 Error = 11.66, resnet_50 Error = 12.16
# Step 96: planet_18 Error = 13.02, resnet_18 Error = 12.41, resnet_50 Error = 12.08
# Step 120: planet_18 Error = 12.70, resnet_18 Error = 11.70, resnet_50 Error = 11.98
# Step 144: planet_18 Error = 12.87, resnet_18 Error = 11.74, resnet_50 Error = 12.17
# Planet18 last avg_loss_planet_18 : 0.05124170338967815, Resnet18 last avg_loss_resnet_18 : 0.04139658622443676, Resnet50 last avg_loss_resnet_50 : 0.03873816039413214
# Planet18 scheduler: 5, Resnet18 scheduler: 3, Resnet50 scheduler: 0
#
# Epoch 96/100
# Current LR - Planet18: 0.000000, ResNet18: 0.000000, ResNet50: 0.000000
# Step 24: planet_18 Error = 12.56, resnet_18 Error = 11.91, resnet_50 Error = 12.23
# Step 48: planet_18 Error = 12.70, resnet_18 Error = 11.99, resnet_50 Error = 11.94
# Step 72: planet_18 Error = 12.29, resnet_18 Error = 11.97, resnet_50 Error = 11.95
# Step 96: planet_18 Error = 12.53, resnet_18 Error = 11.62, resnet_50 Error = 11.91
# Step 120: planet_18 Error = 12.67, resnet_18 Error = 11.62, resnet_50 Error = 12.12
# Step 144: planet_18 Error = 12.63, resnet_18 Error = 11.65, resnet_50 Error = 11.81
# Planet18 last avg_loss_planet_18 : 0.019037255184230162, Resnet18 last avg_loss_resnet_18 : 0.02746695454698056, Resnet50 last avg_loss_resnet_50 : 0.027188130567083135
# Planet18 scheduler: 0, Resnet18 scheduler: 4, Resnet50 scheduler: 1
#
# Epoch 97/100
# Current LR - Planet18: 0.000000, ResNet18: 0.000000, ResNet50: 0.000000
# Step 24: planet_18 Error = 12.81, resnet_18 Error = 11.62, resnet_50 Error = 12.11
# Step 48: planet_18 Error = 12.23, resnet_18 Error = 11.66, resnet_50 Error = 12.12
# Step 72: planet_18 Error = 13.02, resnet_18 Error = 11.78, resnet_50 Error = 11.73
# Step 96: planet_18 Error = 12.77, resnet_18 Error = 11.71, resnet_50 Error = 11.84
# Step 120: planet_18 Error = 12.67, resnet_18 Error = 11.55, resnet_50 Error = 12.33
# Step 144: planet_18 Error = 12.66, resnet_18 Error = 11.85, resnet_50 Error = 11.87
# Planet18 last avg_loss_planet_18 : 0.01338491722708568, Resnet18 last avg_loss_resnet_18 : 0.02526188938645646, Resnet50 last avg_loss_resnet_50 : 0.03123882222280372
# Planet18 scheduler: 1, Resnet18 scheduler: 5, Resnet50 scheduler: 2
#
# Epoch 98/100
# Current LR - Planet18: 0.000000, ResNet18: 0.000000, ResNet50: 0.000000
# Step 24: planet_18 Error = 12.44, resnet_18 Error = 11.80, resnet_50 Error = 12.01
# Step 48: planet_18 Error = 12.87, resnet_18 Error = 11.44, resnet_50 Error = 11.93
# Step 72: planet_18 Error = 12.87, resnet_18 Error = 11.60, resnet_50 Error = 11.71
# Step 96: planet_18 Error = 12.56, resnet_18 Error = 11.74, resnet_50 Error = 11.62
# Step 120: planet_18 Error = 12.56, resnet_18 Error = 11.71, resnet_50 Error = 12.09
# Step 144: planet_18 Error = 12.44, resnet_18 Error = 11.89, resnet_50 Error = 11.90
# Planet18 last avg_loss_planet_18 : 0.018078230459650513, Resnet18 last avg_loss_resnet_18 : 0.021279772219713777, Resnet50 last avg_loss_resnet_50 : 0.00759736358304508
# Planet18 scheduler: 2, Resnet18 scheduler: 0, Resnet50 scheduler: 3
#
# Epoch 99/100
# Current LR - Planet18: 0.000000, ResNet18: 0.000000, ResNet50: 0.000000
# Step 24: planet_18 Error = 12.82, resnet_18 Error = 11.90, resnet_50 Error = 12.25
# Step 48: planet_18 Error = 12.78, resnet_18 Error = 12.02, resnet_50 Error = 11.83
# Step 72: planet_18 Error = 13.06, resnet_18 Error = 12.00, resnet_50 Error = 11.90
# Step 96: planet_18 Error = 12.50, resnet_18 Error = 12.04, resnet_50 Error = 11.69
# Step 120: planet_18 Error = 12.69, resnet_18 Error = 11.92, resnet_50 Error = 12.03
# Step 144: planet_18 Error = 12.95, resnet_18 Error = 11.86, resnet_50 Error = 11.73
# Planet18 last avg_loss_planet_18 : 0.007608883133798372, Resnet18 last avg_loss_resnet_18 : 0.02039484807755798, Resnet50 last avg_loss_resnet_50 : 0.03357682049681898
# Planet18 scheduler: 3, Resnet18 scheduler: 1, Resnet50 scheduler: 4
#
# Epoch 100/100
# Current LR - Planet18: 0.000000, ResNet18: 0.000000, ResNet50: 0.000000
# Step 24: planet_18 Error = 12.87, resnet_18 Error = 11.65, resnet_50 Error = 11.99
# Step 48: planet_18 Error = 12.51, resnet_18 Error = 11.77, resnet_50 Error = 12.09
# Step 72: planet_18 Error = 12.65, resnet_18 Error = 11.63, resnet_50 Error = 11.93
# Step 96: planet_18 Error = 12.76, resnet_18 Error = 11.96, resnet_50 Error = 12.34
# Step 120: planet_18 Error = 12.29, resnet_18 Error = 12.11, resnet_50 Error = 11.81
# Step 144: planet_18 Error = 12.55, resnet_18 Error = 12.04, resnet_50 Error = 11.97
# Planet18 last avg_loss_planet_18 : 0.06250035593984649, Resnet18 last avg_loss_resnet_18 : 0.030234604819270317, Resnet50 last avg_loss_resnet_50 : 0.034633807255886495
# Planet18 scheduler: 4, Resnet18 scheduler: 2, Resnet50 scheduler: 5

# %%
# 모델 저장 (최종 결과 보존)
torch.save(planet_18.state_dict(), 'planet_18_scheduler_epoch100.pth')
torch.save(resnet_18.state_dict(), 'resnet_18_scheduler_epoch100.pth')
torch.save(resnet_50.state_dict(), 'resnet_50_scheduler_epoch100.pth')

# %%
import matplotlib.pyplot as plt

# PlainNet과 ResNet 비교 그래프
plt.figure(figsize=(15, 5))
# 손실 비교 그래프
plt.subplot(1, 3, 1)
#plt.plot(planet_18_loss, label='PlainNet-18', color='blue', linewidth=1)
plt.plot(resnet_18_loss, label='ResNet-18', color='red', linewidth=1)
plt.plot(resnet_50_loss, label='ResNet-50', color='green', linewidth=1)
plt.title("Loss Comparison")
plt.xlabel("Step")
plt.ylabel("Loss")
plt.legend()
plt.grid(True, alpha=0.3)

# 오류율 step x 값 보정
x_values = [i * 24 for i in range(len(planet_18_error))]

# 오류율 비교 그래프
plt.subplot(1, 3, 2)
plt.plot(x_values, planet_18_error, label='PlainNet-18', color='blue', linewidth=2)
plt.plot(x_values, resnet_18_error, label='ResNet-18', color='red', linewidth=2)
plt.plot(x_values, resnet_50_error, label='ResNet-50', color='green', linewidth=2)
plt.title("Error Rate Comparison")
plt.xlabel("Step")
plt.ylabel("Error (%)")
plt.legend()
plt.grid(True, alpha=0.3)

# 오류율만 따로 비교 (더 큰 그래프)
plt.subplot(1, 3, 3)
plt.plot(x_values, planet_18_error, label='PlainNet-18', color='blue', linewidth=2, marker='o', markersize=3)
plt.plot(x_values, resnet_18_error, label='ResNet-18', color='red', linewidth=2, marker='s', markersize=3)
plt.plot(x_values, resnet_50_error, label='ResNet-50', color='green', linewidth=2, marker='^', markersize=3)
plt.title("Error Rate Comparison (Detailed)")
plt.xlabel("Step")
plt.ylabel("Error (%)")
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# 마지막 부분 확대 그래프 (Step 8000-14000)
plt.figure(figsize=(12, 8))

# Step 8000-14000 범위 필터링
start_step = 8000
end_step = 14000

# 해당 범위의 인덱스 찾기
start_idx = start_step // 24  # 24 스텝마다 평가하므로
end_idx = end_step // 24

# 범위 내 데이터만 추출
filtered_planet_18 = planet_18_error[start_idx:end_idx]
filtered_resnet_18 = resnet_18_error[start_idx:end_idx]
filtered_resnet_50 = resnet_50_error[start_idx:end_idx]
filtered_x_values = x_values[start_idx:end_idx]

# 확대된 오류율 비교 그래프
plt.plot(filtered_x_values, filtered_planet_18, label='PlainNet-18', color='blue', linewidth=3, marker='o', markersize=4)
plt.plot(filtered_x_values, filtered_resnet_18, label='ResNet-18', color='red', linewidth=3, marker='s', markersize=4)
plt.plot(filtered_x_values, filtered_resnet_50, label='ResNet-50', color='green', linewidth=3, marker='^', markersize=4)

plt.title("Error Rate Comparison (Step 8000-14000)", fontsize=16, fontweight='bold')
plt.xlabel("Step", fontsize=14)
plt.ylabel("Error (%)", fontsize=14)
plt.legend(fontsize=12)
plt.grid(True, alpha=0.3)
plt.xlim(start_step, end_step)

# Y축 범위를 데이터에 맞게 조정
if filtered_planet_18 and filtered_resnet_18 and filtered_resnet_50:
    all_errors = filtered_planet_18 + filtered_resnet_18 + filtered_resnet_50
    y_min = min(all_errors) - 1
    y_max = max(all_errors) + 1
    plt.ylim(y_min, y_max)

plt.tight_layout()
plt.show()

# %%
# 최종 테스트 오류율 비교
planet_18_test_top1_error = evaluate_model(planet_18, test_loader)
resnet_18_test_top1_error = evaluate_model(resnet_18, test_loader)
resnet_50_test_top1_error = evaluate_model(resnet_50, test_loader)  

planet_18_test_top5_error = evaluate_model(planet_18, test_loader, is_top5=True)
resnet_18_test_top5_error = evaluate_model(resnet_18, test_loader, is_top5=True)
resnet_50_test_top5_error = evaluate_model(resnet_50, test_loader, is_top5=True)

print(f"Planet-18 Top1 Error: {planet_18_test_top1_error:.2f}%, Top5 Error: {planet_18_test_top5_error:.2f}%")
print(f"ResNet-18 Top1 Error: {resnet_18_test_top1_error:.2f}%, Top5 Error: {resnet_18_test_top5_error:.2f}%")
print(f"ResNet-50 Top1 Error: {resnet_50_test_top1_error:.2f}%, Top5 Error: {resnet_50_test_top5_error:.2f}%")
# Out:
# Planet-18 Top1 Error: 12.10%, Top5 Error: 0.46%
# ResNet-18 Top1 Error: 11.03%, Top5 Error: 0.43%
# ResNet-50 Top1 Error: 11.55%, Top5 Error: 0.45%
